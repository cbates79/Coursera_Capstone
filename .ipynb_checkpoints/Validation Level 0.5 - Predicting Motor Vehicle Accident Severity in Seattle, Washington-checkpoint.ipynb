# %% [markdown]
# <h1 id="title">Validation Ratio 0.5 - Predicting Motor Vehicle Accident Severity in Seattle, Washington<\h1>

# %%
validation_ratio = .5
training_ratio = 1 - validation_ratio

# %%
# Import packages and modules.
import io
import itertools
import matplotlib as mpl
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import os
import pandas as pd
import pylab as pl
import scipy
import scipy.optimize as opt
import seaborn as sns
import sklearn
import sys
import timeit
import warnings
from matplotlib.ticker import NullFormatter
from scipy import optimize
from scipy.optimize import curve_fit
from scipy.sparse import csr_matrix
from sklearn import linear_model
from sklearn import metrics
from sklearn import pipeline
from sklearn import preprocessing
from sklearn import svm
from sklearn import tree
from sklearn import utils
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import jaccard_score
from sklearn.metrics import log_loss
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.utils import resample
from sklearn.utils import shuffle
from sklearn.exceptions import ConvergenceWarning
from timeit import default_timer
# %matplotlib inline

# %%
warnings.filterwarnings("ignore", category=ConvergenceWarning,
                        module="sklearn")

# %%
# Define the starting time for this notebook. 
notebook_start_time = default_timer()

# %%
# This function computes the time elapsed in seconds from the 
# time represented by the first parameter (start_time)
# to the time represented by the second parameter (end_time)
# This function requires the os package to be imported.
def elapsed_time(start_time = notebook_start_time):
    return default_timer() - start_time

# %%
# This function prints the time elapsed in seconds from the 
# time represented by the first parameter (start_time)
# to the time represented by the second parameter (end_time)
# This function requires the os package to be imported.
def print_elapsed_time(start_time = notebook_start_time):
    print("Elapsed time is", elapsed_time(start_time), "seconds.")
    return None

# %%
# Create a list of display options.
list_of_display_options_fully_qualified_names = str(\
"pd.options.display.chop_threshold, pd.options.display.float_format, pd.options.display.max_info_columns, pd.options.display.notebook_repr_html, \
pd.options.display.colheader_justify, pd.options.display.html, pd.options.display.max_info_rows, pd.options.display.pprint_nest_depth, \
pd.options.display.column_space, pd.options.display.large_repr, pd.options.display.max_rows, pd.options.display.precision, \
pd.options.display.date_dayfirst, pd.options.display.latex, pd.options.display.max_seq_items, pd.options.display.show_dimensions, \
pd.options.display.date_yearfirst, pd.options.display.max_categories, pd.options.display.memory_usage, pd.options.display.unicode, \
pd.options.display.encoding, pd.options.display.max_columns, pd.options.display.min_rows, pd.options.display.width, \
pd.options.display.expand_frame_repr, pd.options.display.max_colwidth, pd.options.display.multi_sparse").split(sep=', ')

# Initialize an empty list to store all the short names for display options.
list_of_display_options_short_names = list()
# For each fully qualified option name,
# get the option's short name and add it to the list of short names.
for fully_qualified_option_name in list_of_display_options_fully_qualified_names:
    # Get short option name.
    short_option_name = fully_qualified_option_name.split(sep='.')[-1]
    
    # Add short option name to list of display option short names.
    list_of_display_options_short_names.append(short_option_name)

# Define dictionary of display option settings.
dict_of_display_option_settings_short_names=\
{"max_info_columns": 1000,\
"colheader_justify": "right",\
"max_info_rows": 1000000,\
"column_space": 1000,\
"max_rows": 1000000,\
"precision": 9,\
"max_seq_items": 1000000000000,\
"show_dimensions": True,\
"max_categories": 100,\
"memory_usage": True,\
"max_columns": 1000,\
"max_colwidth": 1000,\
"float_format": lambda x: '%.9f' % x}

# Set pandas display options using dictionary of short names,
# and display the options/value pairs.
print("Setting display options...")
for key in list(dict_of_display_option_settings_short_names.keys()):
    # Set display option.
    pd.set_option(key, dict_of_display_option_settings_short_names[key])
    # Print display option name and value.
    print(key, ": ", pd.get_option(key), sep='')
# Out:
# Setting display options...
# max_info_columns: 1000
# colheader_justify: right
# max_info_rows: 1000000
# column_space: 1000
# max_rows: 1000000
# precision: 9
# max_seq_items: 1000000000000
# show_dimensions: True
# max_categories: 100
# memory_usage: True
# max_columns: 1000
# max_colwidth: 1000
# float_format: <function <lambda> at 0x7f0b8753e0d0>

# %%
# Set seed for random number generator.
# seed = np.int(os.times()[4]) # Use this line for better pseudo-random behavior.
seed = 42
print(seed)
# Out:
# 42

# %%
# Attribute Information URL: https://www.seattle.gov/Documents/Departments/SDOT/GIS/Collisions_OD.pdf
# Read the Collisions Data CSV file and store it as a DataFrame.
# url="https://opendata.arcgis.com/datasets/5b5c745e0f1f48e7a53acec63a0022ab_0.csv" # HTTPError at 202009151050, using local copy of .csv instead.
# print(os.listdir("..")) # Print list of contents of current working directory.
local_path_to_csv = '~/IBM Data Science Professional Certificate Course/Course 9 - Applied Data Science Capstone/projects/Collisions.csv'
df=pd.read_csv(local_path_to_csv, low_memory=False)

# %%
# View the first few rows of the collisions DataFrame.
df.head()
# Out:
#                X            Y  OBJECTID  INCKEY  COLDETKEY   REPORTNO  \
# 0 -122.320757054 47.609407946         1  328476     329976    EA08706
# 1 -122.319560827 47.662220664         2  328142     329642    EA06882
# 2 -122.327524508 47.604393273         3   20700      20700    1181833
# 3 -122.327524934 47.708621579         4  332126     333626  M16001640
# 4 -122.292120049 47.559009080         5  328238     329738    3857118
#
#       STATUS ADDRTYPE  INTKEY  \
# 0    Matched    Block     nan
# 1    Matched    Block     nan
# 2  Unmatched    Block     nan
# 3  Unmatched    Block     nan
# 4  Unmatched    Block     nan
#
#                                                       LOCATION EXCEPTRSNCODE  \
# 0              BROADWAY BETWEEN E COLUMBIA ST AND BOYLSTON AVE
# 1               8TH AVE NE BETWEEN NE 45TH E ST AND NE 47TH ST
# 2                         JAMES ST BETWEEN 6TH AVE AND 7TH AVE           NaN
# 3      NE NORTHGATE WAY BETWEEN 1ST AVE NE AND NE NORTHGATE DR
# 4  M L KING JR ER WAY S BETWEEN S ANGELINE ST AND S EDMUNDS ST
#
#   EXCEPTRSNDESC SEVERITYCODE                    SEVERITYDESC COLLISIONTYPE  \
# 0           NaN            1  Property Damage Only Collision     Sideswipe
# 1           NaN            1  Property Damage Only Collision    Parked Car
# 2           NaN            0                         Unknown           NaN
# 3           NaN            0                         Unknown           NaN
# 4           NaN            0                         Unknown           NaN
#
#    PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  INJURIES  SERIOUSINJURIES  \
# 0            2         0            0         2         0                0
# 1            2         0            0         2         0                0
# 2            0         0            0         0         0                0
# 3            0         0            0         0         0                0
# 4            0         0            0         0         0                0
#
#    FATALITIES                 INCDATE               INCDTTM  \
# 0           0  2020/01/22 00:00:00+00  1/22/2020 3:21:00 PM
# 1           0  2020/01/07 00:00:00+00   1/7/2020 8:00:00 AM
# 2           0  2004/01/30 00:00:00+00             1/30/2004
# 3           0  2016/01/23 00:00:00+00             1/23/2016
# 4           0  2020/01/26 00:00:00+00             1/26/2020
#
#                               JUNCTIONTYPE  SDOT_COLCODE  \
# 0  Mid-Block (not related to intersection)  11.000000000
# 1  Mid-Block (not related to intersection)  15.000000000
# 2     Mid-Block (but intersection related)  11.000000000
# 3  Mid-Block (not related to intersection)  11.000000000
# 4  Mid-Block (not related to intersection)  28.000000000
#
#                                                SDOT_COLDESC INATTENTIONIND  \
# 0    MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END AT ANGLE            NaN
# 1  MOTOR VEHICLE STRUCK MOTOR VEHICLE, RIGHT SIDE SIDESWIPE            NaN
# 2    MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END AT ANGLE            NaN
# 3    MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END AT ANGLE            NaN
# 4             MOTOR VEHICLE RAN OFF ROAD - HIT FIXED OBJECT            NaN
#
#   UNDERINFL  WEATHER ROADCOND                LIGHTCOND PEDROWNOTGRNT  \
# 0         N  Raining      Wet  Dark - Street Lights On           NaN
# 1         N    Clear      Dry                 Daylight           NaN
# 2       NaN      NaN      NaN                      NaN           NaN
# 3       NaN      NaN      NaN                      NaN           NaN
# 4       NaN      NaN      NaN                      NaN           NaN
#
#          SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0               nan      NaN         11
# 1               nan      NaN         32
# 2 4030032.000000000      NaN        NaN
# 3               nan      NaN
# 4               nan      NaN
#
#                                                             ST_COLDESC  \
# 0  From same direction - both going straight - both moving - sideswipe
# 1                                               One parked--one moving
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#    SEGLANEKEY  CROSSWALKKEY HITPARKEDCAR
# 0           0             0            N
# 1           0             0            Y
# 2           0             0            N
# 3           0             0            N
# 4           0             0            N
#
# [5 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221389 entries, 0 to 221388
# Data columns (total 40 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   X                213918 non-null  float64
#  1   Y                213918 non-null  float64
#  2   OBJECTID         221389 non-null  int64
#  3   INCKEY           221389 non-null  int64
#  4   COLDETKEY        221389 non-null  int64
#  5   REPORTNO         221389 non-null  object
#  6   STATUS           221389 non-null  object
#  7   ADDRTYPE         217677 non-null  object
#  8   INTKEY           71884 non-null   float64
#  9   LOCATION         216801 non-null  object
#  10  EXCEPTRSNCODE    100986 non-null  object
#  11  EXCEPTRSNDESC    11779 non-null   object
#  12  SEVERITYCODE     221388 non-null  object
#  13  SEVERITYDESC     221389 non-null  object
#  14  COLLISIONTYPE    195159 non-null  object
#  15  PERSONCOUNT      221389 non-null  int64
#  16  PEDCOUNT         221389 non-null  int64
#  17  PEDCYLCOUNT      221389 non-null  int64
#  18  VEHCOUNT         221389 non-null  int64
#  19  INJURIES         221389 non-null  int64
#  20  SERIOUSINJURIES  221389 non-null  int64
#  21  FATALITIES       221389 non-null  int64
#  22  INCDATE          221389 non-null  object
#  23  INCDTTM          221389 non-null  object
#  24  JUNCTIONTYPE     209417 non-null  object
#  25  SDOT_COLCODE     221388 non-null  float64
#  26  SDOT_COLDESC     221388 non-null  object
#  27  INATTENTIONIND   30188 non-null   object
#  28  UNDERINFL        195179 non-null  object
#  29  WEATHER          194969 non-null  object
#  30  ROADCOND         195050 non-null  object
#  31  LIGHTCOND        194880 non-null  object
#  32  PEDROWNOTGRNT    5192 non-null    object
#  33  SDOTCOLNUM       127205 non-null  float64
#  34  SPEEDING         9928 non-null    object
#  35  ST_COLCODE       211976 non-null  object
#  36  ST_COLDESC       195159 non-null  object
#  37  SEGLANEKEY       221389 non-null  int64
#  38  CROSSWALKKEY     221389 non-null  int64
#  39  HITPARKEDCAR     221389 non-null  object
# dtypes: float64(5), int64(12), object(23)
# memory usage: 67.6+ MB

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 9.438390220049769 seconds.

# %% [markdown]
# <h2 id="data_wrangling">Data Wrangling</h2>
#
# Steps for working with missing data:
# <ol>
#     <li>Identify missing data.</li>
#     <li>Deal with missing data.</li>
#     <li>Correct data format.</li>
# </ol>

# %% [markdown]
# <h3 id="identifying_missing_data">Identifying Missing Data</h3>
#
# The metadata document that accompanied the data set indicates that certain columns have "sentinel" values
# that indicate an unknown or missing value. Each of these missing values will first be converted into NaN.
# Subsequently, the NaN values will be dropped from the DataFrame.

# %%
# If any row of the collisions DataFrame contains a sentinel value representing "unknown",
# then replace it with NaN. 
# Sentinels for "unknown" are listed in the metadata document that accompanies the dataset.
df_unknowns_converted_to_nan = df.replace(to_replace=\
{"EXCEPTRSNCODE": " ",\
 "EXCEPTRSNDESC": "Not Enough Information, or Insufficient Location Information",\
 "SEVERITYCODE": "0",\
 "SEVERITYDESC": "Unknown",\
 "JUNCTIONTYPE": "Unknown",\
 "WEATHER": "Unknown",\
 "ROADCOND": "Unknown",\
 "LIGHTCOND": "Unknown",\
 "SDOT_COLCODE": float(0),\
 "SDOT_COLDESC": "NOT ENOUGH INFORMATION / NOT APPLICABLE",\
 "ST_COLCODE": " ",\
 "ST_COLDESC": "Not stated"},\
value=np.nan, inplace=False, limit=None, regex=False, method='pad')

df_unknowns_converted_to_nan.replace(to_replace={"ST_COLCODE": "0", }, value=np.nan, inplace=True, limit=None, regex=False, method='pad')

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 17.41823959699832 seconds.

# %% [markdown]
# <h3 id="deal_with_missing_data">Deal with Missing Data</h3>
#
# <ol>
#     <li>Drop the Data
#         <ol>
#             <li>Drop entire row.</li>
#             <li>Drop entire column.</li>
#         </ol>
#     </li>
#     <li>Replace the Data
#         <ol>
#             <li>Replace data by mean.</li>
#             <li>Replace data by frequency.</li>
#             <li>Replace data based on other functions.</li>
#         </ol>
#     </li>
#
# </ol>

# %% [markdown]
# Whole columns should be dropped only if most entries in the column are empty.

# %%
print(list(df.columns))
# Out:
# ['X', 'Y', 'OBJECTID', 'INCKEY', 'COLDETKEY', 'REPORTNO', 'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE', 'EXCEPTRSNDESC', 'SEVERITYCODE', 'SEVERITYDESC', 'COLLISIONTYPE', 'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES', 'INCDATE', 'INCDTTM', 'JUNCTIONTYPE', 'SDOT_COLCODE', 'SDOT_COLDESC', 'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND', 'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING', 'ST_COLCODE', 'ST_COLDESC', 'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR']

# %%
# Drop any column from the collisions DataFrame if it satisfies at least one of the following conditions:
# 1) more than 15% of the column's data is NaN;
# 2) the column only contains unique identification keys, or information not useful for model building;
# 3) the column's data is categorical but does not fit into a small (< 15) number of categories;
# 4) information in the column is redundant because it is already represented by another column;
# 5) it is not clear how to interpret the column's data.
list_of_columns_to_drop = ["ADDRTYPE",\
                           "STATUS",\
                           "OBJECTID",\
                           "INCKEY",\
                           "COLDETKEY",\
                           "REPORTNO",\
                           "INTKEY",\
                           "LOCATION",\
                           "EXCEPTRSNCODE",\
                           "EXCEPTRSNDESC",\
                           "SEVERITYDESC",\
                           "INCDATE",\
                           "INCDTTM",\
                           "JUNCTIONTYPE",\
                           "SDOT_COLCODE",\
                           "SDOT_COLDESC",\
                           "INATTENTIONIND",\
                           "UNDERINFL",\
                           "PEDROWNOTGRNT",\
                           "SDOTCOLNUM",\
                           "SPEEDING",\
                           "ST_COLCODE",\
                           "ST_COLDESC",\
                           "SEGLANEKEY",\
                           "CROSSWALKKEY",\
                           "HITPARKEDCAR"]

# %%
# Drop the selected columns from the DataFrame after converting unknowns to NaN.
# Store the result in a new DataFrame.
df_drop_columns = df_unknowns_converted_to_nan.drop(columns=list_of_columns_to_drop, inplace=False)

# %%
# Drop any row that contains at least one NaN.
df_drop_columns_and_rows = df_drop_columns.dropna(axis="index", how="any", thresh=None, subset=None, inplace=False)

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 18.585601163096726 seconds.

# %% [markdown]
# <h3 id="correct_data_format">Correct Data Format</h3>
#
# Ensure that each data type is appropriate for the corresponding feature.
# Cast columns of type "object" as type "category", but leave all other column types unaltered.

# %%
# Create new DataFrame to store converted data types.
df_converted = pd.DataFrame()

for column in list(df_drop_columns_and_rows.columns):
    if (df_drop_columns_and_rows[column].dtype in [np.dtype('object')]):
        df_converted[column] = df_drop_columns_and_rows[column].astype('category')
    # Copy all other columns to new DataFrame without changing their types.
    else:
        df_converted[column] = df_drop_columns_and_rows[column]

# %%
# Create DataFrame of categorical or integer columns, inclusive.
df_categorical = df_converted.select_dtypes(include=["category", "integer"])

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 19.272528839064762 seconds.

# %% [markdown]
# <h2 id="feature_selection">Feature selection</h2>

# %% [markdown]
# #### Features before One-Hot Encoding

# %%
df_categorical.head()
# Out:
#   SEVERITYCODE COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0            1     Sideswipe            2         0            0         2
# 1            1    Parked Car            2         0            0         2
# 5            1    Rear Ended            2         0            0         2
# 6            1         Other            2         0            0         1
# 8            1     Sideswipe            2         0            0         2
#
#    INJURIES  SERIOUSINJURIES  FATALITIES   WEATHER ROADCOND  \
# 0         0                0           0   Raining      Wet
# 1         0                0           0     Clear      Dry
# 5         0                0           0     Clear      Dry
# 6         0                0           0     Clear      Wet
# 8         0                0           0  Overcast      Dry
#
#                  LIGHTCOND
# 0  Dark - Street Lights On
# 1                 Daylight
# 5                 Daylight
# 6                 Daylight
# 8                 Daylight
#
# [5 rows x 12 columns]

# %%
df_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171872 entries, 0 to 221388
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SEVERITYCODE     171872 non-null  category
#  1   COLLISIONTYPE    171872 non-null  category
#  2   PERSONCOUNT      171872 non-null  int64
#  3   PEDCOUNT         171872 non-null  int64
#  4   PEDCYLCOUNT      171872 non-null  int64
#  5   VEHCOUNT         171872 non-null  int64
#  6   INJURIES         171872 non-null  int64
#  7   SERIOUSINJURIES  171872 non-null  int64
#  8   FATALITIES       171872 non-null  int64
#  9   WEATHER          171872 non-null  category
#  10  ROADCOND         171872 non-null  category
#  11  LIGHTCOND        171872 non-null  category
# dtypes: category(5), int64(7)
# memory usage: 11.3 MB

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 19.65350675699301 seconds.

# %% [markdown]
# <h2 id="imbalanced_data">Dealing with Imbalanced Data</h2>

# %% [markdown]
# Because the data is imbalanced, we split the DataFrame into four DataFrames, one for each value of the SEVERITYCODE feature.

# %%
print("SEVERITYCODE relative frequencies:")
print(df_categorical["SEVERITYCODE"].value_counts(normalize=True, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 1    0.657943120
# 2    0.323036911
# 2b   0.017111571
# 3    0.001908397
# Name: SEVERITYCODE, Length: 4, dtype: float64

# %%
print("SEVERITYCODE relative frequencies:")
print(df_categorical["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 1     113082
# 2      55521
# 2b      2941
# 3        328
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
df_class_1 = df_categorical[df_categorical['SEVERITYCODE'] == '1']
df_class_2 = df_categorical[df_categorical['SEVERITYCODE'] == '2']
df_class_2b = df_categorical[df_categorical['SEVERITYCODE'] == '2b']
df_class_3 = df_categorical[df_categorical['SEVERITYCODE'] == '3']

# %%
print("SEVERITYCODE relative frequencies:")
print(df_class_1["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 1     113082
# 3          0
# 2b         0
# 2          0
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
print("SEVERITYCODE relative frequencies:")
print(df_class_2["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 2     55521
# 3         0
# 2b        0
# 1         0
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
print("SEVERITYCODE relative frequencies:")
print(df_class_2b["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 2b    2941
# 3        0
# 2        0
# 1        0
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
print("SEVERITYCODE relative frequencies:")
print(df_class_3["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 3     328
# 2b      0
# 2       0
# 1       0
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
# Store and print the size of the all classes.
class_1_size = len(df_class_1)
class_2_size = len(df_class_2)
class_2b_size = len(df_class_2b)
class_3_size = len(df_class_3)
print('class 1 size =', class_1_size)
print('class 2 size =', class_2_size)
print('class 2b size =', class_2b_size)
print('class 3 size =', class_3_size)
print()
# Store and print the size of the minority class.
minority_class_size = len(df_class_3)
print('minority class size =', minority_class_size)
# Out:
# class 1 size = 113082
# class 2 size = 55521
# class 2b size = 2941
# class 3 size = 328
#
# minority class size = 328

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 20.72517133806832 seconds.

# %% [markdown]
# <h2 id='sample_size_class_3'>Sample all Classes Equally and Create a Balanced Training Set<\h2>

# %%
# This sampling parameter provides conventient control for the oversampling of the minority classes
# and, consequently, for the undersampling of the majority classes.
#sampling_parameter = 1 * class_3_size

# %%
# Set the size of sample to take from each class of accident severity.
# To balance the dataset, ensure that all samples are of the same size.
# sample_size_class_1 = np.int(sampling_parameter)
# sample_size_class_2 = np.int(sampling_parameter)
# sample_size_class_2b = np.int(sampling_parameter)
# sample_size_class_3 = np.int(sampling_parameter)

# %%
# This parameter controls the size of the training set generated from each class,
# as a floating point multiple of the size of the minority class.
train_size = training_ratio * class_3_size

# %%
# Set the size of sample to take from each class of accident severity to generate a training set.
# To balance the dataset, ensure that all samples are of the same size.
train_size_class_1 = np.int(train_size)
train_size_class_2 = np.int(train_size)
train_size_class_2b = np.int(train_size)
train_size_class_3 = np.int(train_size)

# %%
# Sample all classes equally, with the number of samples equal to the size of class '3'.
# Replacement flag is boolean with value set as follows:
# If class_size > sample_size, then parameter replace is passed the value True.
# Otherwise, parameter replace is passed the value False.
#replaceFlag = bool(class_1_size < sample_size_class_1)
#print('bool(class_1_size < sample_size_class_1) = %s' % bool(class_1_size < sample_size_class_1))
#df_class_1_sampled = df_class_1.sample(n=sample_size_class_1,replace=replaceFlag, axis='index', random_state=seed)
df_class_1_train, df_class_1_validate = train_test_split(df_class_1, train_size=train_size_class_1, random_state=seed)

#replaceFlag = bool(class_2_size < sample_size_class_2)
#print('bool(class_2_size < sample_size_class_2) = %s' % bool(class_2_size < sample_size_class_2))
#df_class_2_sampled = df_class_2.sample(n=sample_size_class_2, replace=replaceFlag, axis='index', random_state=seed)
df_class_2_train, df_class_2_validate = train_test_split(df_class_2, train_size=train_size_class_2, random_state=seed)

#replaceFlag = bool(class_2b_size < sample_size_class_2b)
#print('bool(class_2b_size < sample_size_class_2b) = %s' % bool(class_2b_size < sample_size_class_2b))
#df_class_2b_sampled = df_class_2b.sample(n=sample_size_class_2b, replace=replaceFlag, axis='index', random_state=seed)
df_class_2b_train, df_class_2b_validate = train_test_split(df_class_2b, train_size=train_size_class_2b, random_state=seed)

#replaceFlag = bool(class_3_size < sample_size_class_3)
#print('bool(class_3_size < sample_size_class_3) = %s' % bool(class_3_size < sample_size_class_3))
#df_class_3_sampled = df_class_3.sample(n=sample_size_class_3, replace=replaceFlag, axis='index', random_state=seed)
df_class_3_train, df_class_3_validate = train_test_split(df_class_3, train_size=train_size_class_3, random_state=seed)

# %%
# Produce a new DataFrame by concatenating the minority class's DataFrame with the undersampled resamples of the non-minority classes.
# df_balanced_not_shuffled = pd.concat([df_class_1_sampled, df_class_2_sampled, df_class_2b_sampled, df_class_3_sampled], axis='index')

# %%
# Produce a balanced (but currently unshuffled) DataFrame for training the models.
df_balanced_not_shuffled = pd.concat([df_class_1_train, df_class_2_train, df_class_2b_train, df_class_3_train], axis='index')

# Produce a possibly imbalanced (but currently unshuffled) DataFrame for validating the models.
df_validate_not_shuffled = pd.concat([df_class_1_validate, df_class_2_validate, df_class_2b_validate, df_class_3_validate], axis='index')

# %%
# Shuffle the balanced DataFrame and store it for training.
df_balanced = shuffle(df_balanced_not_shuffled, random_state=seed)

# Shuffle the unbalanced DataFrame and store it for validation.
df_validate = shuffle(df_validate_not_shuffled, random_state=seed)

# %%
# Verify the new DataFrame is balanced.
print("SEVERITYCODE relative frequencies:")
print(df_balanced["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 3     164
# 2b    164
# 2     164
# 1     164
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
# Verify the new DataFrame is balanced.
print("SEVERITYCODE relative frequencies:")
print(df_balanced["SEVERITYCODE"].value_counts(normalize=True, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 3    0.250000000
# 2b   0.250000000
# 2    0.250000000
# 1    0.250000000
# Name: SEVERITYCODE, Length: 4, dtype: float64

# %% [markdown]
# Let's define a feature set represented by the DataFrame X.

# %%
X = df_balanced.drop(columns=['SEVERITYCODE', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES'], inplace=False)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 656 entries, 75784 to 88240
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   COLLISIONTYPE  656 non-null    category
#  1   PERSONCOUNT    656 non-null    int64
#  2   PEDCOUNT       656 non-null    int64
#  3   PEDCYLCOUNT    656 non-null    int64
#  4   VEHCOUNT       656 non-null    int64
#  5   WEATHER        656 non-null    category
#  6   ROADCOND       656 non-null    category
#  7   LIGHTCOND      656 non-null    category
# dtypes: category(4), int64(4)
# memory usage: 29.7 KB

# %% [markdown]
# We also define the data for the target variable, SEVERITYCODE, by the array y:

# %%
y = df_balanced["SEVERITYCODE"].to_numpy()

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 22.60699102305807 seconds.

# %% [markdown]
# ## Transform the Data

# %% [markdown]
# We normalize the data by transforming it so that it is compatible
# with the machine learning estimators we use in this notebook.
# We use special care with sparse matrix data so as to not destroy the
# structure.

# %%
# Create a OneHotEncoder and fit it to the features.
# Transform the data into a sparse matrix by passing the parameter sparse=True by default.
start_time = default_timer()
print("Fitting OneHotEncoder to training data...")
encoder = OneHotEncoder(sparse=True, handle_unknown='ignore')
#encoder.fit(df_categorical.drop(columns=['SEVERITYCODE', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES'], inplace=False))
encoder.fit(X)
X = encoder.transform(X)
print("Completed in", elapsed_time(start_time), "seconds.")
# Display the categories of the encoder.
print(encoder.get_feature_names())
# Out:
# Fitting OneHotEncoder to training data...
# Completed in 0.03713626100216061 seconds.
# ['x0_Angles' 'x0_Cycles' 'x0_Head On' 'x0_Left Turn' 'x0_Other'
#  'x0_Parked Car' 'x0_Pedestrian' 'x0_Rear Ended' 'x0_Right Turn'
#  'x0_Sideswipe' 'x1_0' 'x1_1' 'x1_2' 'x1_3' 'x1_4' 'x1_5' 'x1_6' 'x1_7'
#  'x1_8' 'x1_11' 'x1_12' 'x1_93' 'x2_0' 'x2_1' 'x2_2' 'x3_0' 'x3_1' 'x3_2'
#  'x4_1' 'x4_2' 'x4_3' 'x4_4' 'x4_5' 'x4_7' 'x4_8' 'x5_Clear'
#  'x5_Fog/Smog/Smoke' 'x5_Other' 'x5_Overcast' 'x5_Raining'
#  'x5_Sleet/Hail/Freezing Rain' 'x5_Snowing' 'x6_Dry' 'x6_Ice' 'x6_Wet'
#  'x7_Dark - No Street Lights' 'x7_Dark - Street Lights Off'
#  'x7_Dark - Street Lights On' 'x7_Dawn' 'x7_Daylight' 'x7_Dusk']

# %%
type(X)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
X.shape
# Out:
# (656, 51)

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 23.045564720989205 seconds.

# %% [markdown]
# <h2 id="logistic_regression">Building a Logistic Regression Model<\h2>

# %%
t0 = default_timer()
#kfold_cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
number_of_folds = 10
logistic_regression_clf = make_pipeline(\
    StandardScaler(with_mean=False),\
    LogisticRegression(solver='saga', multi_class='auto', penalty='l1', max_iter=100, verbose=10, n_jobs=-1, random_state=seed), verbose=True)
scoring = ['f1_macro', 'f1_weighted', 'neg_log_loss', 'precision_macro', 'precision_weighted', 'recall_macro', 'recall_weighted']
logistic_regression_scores = cross_validate(logistic_regression_clf, X, y, scoring=scoring, n_jobs=-1, cv=number_of_folds, return_estimator=True)
print("Logistic regression score keys:", sorted(logistic_regression_scores.keys()))
print('Logistic Regression classifiers constructed in %f seconds.' % elapsed_time(t0))
# Out:
# Logistic regression score keys: ['estimator', 'fit_time', 'score_time', 'test_f1_macro', 'test_f1_weighted', 'test_neg_log_loss', 'test_precision_macro', 'test_precision_weighted', 'test_recall_macro', 'test_recall_weighted']
# Logistic Regression classifiers constructed in 9.120875 seconds.

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 32.30756515508983 seconds.

# %% [markdown]
# <h2 id="support_vector_machine">Building a Support Vector Machine<\h2>

# %%
t0 = default_timer()
number_of_folds = 10
#kfold_cv = StratifiedKFold(n_splits=number_of_folds, shuffle=True, random_state=seed)
linear_svc_clf = make_pipeline(\
    StandardScaler(with_mean=False),\
    LinearSVC(penalty='l1', dual=False, random_state=seed, max_iter=100), verbose=True)
scoring = ['f1_macro', 'f1_weighted', 'precision_macro', 'precision_weighted', 'recall_macro', 'recall_weighted']
linear_svc_scores = cross_validate(linear_svc_clf, X, y, scoring=scoring, n_jobs=-1, cv=number_of_folds, return_estimator=True)
print("Support Vector Machine score keys:", sorted(linear_svc_scores.keys()))
print('Support Vector Machine classifiers constructed in %f seconds.' % elapsed_time(t0))
# Out:
# Support Vector Machine score keys: ['estimator', 'fit_time', 'score_time', 'test_f1_macro', 'test_f1_weighted', 'test_precision_macro', 'test_precision_weighted', 'test_recall_macro', 'test_recall_weighted']
# Support Vector Machine classifiers constructed in 0.968820 seconds.

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 33.432865792070515 seconds.

# %% [markdown]
# <h2 id="knn_classifier">Building a k-Nearsest Neighbors Classifier<\h2>

# %%
t0 = default_timer()
number_of_folds = 10
# Set maximum number of neighbors based on number of samples and number of folds to prevent errors.
maximum_number_of_neighbors = min(200, np.int((X.shape[0] * (1 - 1 / number_of_folds))) - 1) # Take the smaller of the two parameters for min().
k_neighbors_clf = make_pipeline(\
    StandardScaler(with_mean=False),\
    KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski', metric_params=None, n_jobs=-1, p=1, weights='distance'), verbose=True)
# Only us an odd number of neighbors to avoid ties.
#grid_parameters = {'n_neighbors': range(3, maximum_number_of_neighbors, 2),\
#                   'weights': ['distance', 'uniform']} 
grid_parameters = {'kneighborsclassifier__n_neighbors': range(3, maximum_number_of_neighbors, 2)}
scoring = ['recall_weighted']
grid_search_cv = GridSearchCV(k_neighbors_clf, param_grid=grid_parameters,\
                              scoring=scoring, \
                              n_jobs=-1, refit='recall_weighted', cv=number_of_folds, verbose=100, pre_dispatch=2**8, error_score='raise',\
                              return_train_score=False)
grid_search_cv.fit(X, y)
# Out:
# Fitting 10 folds for each of 99 candidates, totalling 990 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 185 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 186 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 187 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done 191 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 193 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done 195 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:   22.2s
# [Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:   22.2s
# [Parallel(n_jobs=-1)]: Done 198 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 201 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 203 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 206 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done 207 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done 208 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 209 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=-1)]: Done 211 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 212 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 214 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 215 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 217 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 219 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done 220 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 222 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 223 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 227 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done 235 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done 236 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:   25.6s
# [Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 245 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=-1)]: Done 246 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 251 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done 253 tasks      | elapsed:   26.8s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:   26.8s
# [Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 258 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 259 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 261 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=-1)]: Done 262 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done 265 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done 267 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done 268 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=-1)]: Done 269 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=-1)]: Done 270 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 271 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done 274 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 275 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 276 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 277 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=-1)]: Done 278 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=-1)]: Done 279 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 281 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 282 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 283 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 285 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 286 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 287 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 288 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 289 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 290 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 291 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 293 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 294 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 295 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 296 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 297 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 299 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 301 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 302 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 303 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 307 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 309 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done 310 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 311 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 313 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 314 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 315 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=-1)]: Done 316 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 317 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=-1)]: Done 318 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 319 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=-1)]: Done 320 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 321 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 323 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-1)]: Done 324 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done 326 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=-1)]: Done 327 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 328 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=-1)]: Done 329 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 331 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done 332 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=-1)]: Done 334 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done 335 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=-1)]: Done 336 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=-1)]: Done 337 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 338 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done 339 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done 340 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 342 tasks      | elapsed:   34.6s
# [Parallel(n_jobs=-1)]: Done 343 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 344 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 345 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 346 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 347 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done 348 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=-1)]: Done 350 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=-1)]: Done 351 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done 353 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done 354 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done 355 tasks      | elapsed:   35.7s
# [Parallel(n_jobs=-1)]: Done 356 tasks      | elapsed:   35.7s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:   35.8s
# [Parallel(n_jobs=-1)]: Done 358 tasks      | elapsed:   35.9s
# [Parallel(n_jobs=-1)]: Done 359 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed:   36.1s
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed:   36.2s
# [Parallel(n_jobs=-1)]: Done 362 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done 363 tasks      | elapsed:   36.4s
# [Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:   36.4s
# [Parallel(n_jobs=-1)]: Done 365 tasks      | elapsed:   36.5s
# [Parallel(n_jobs=-1)]: Done 366 tasks      | elapsed:   36.5s
# [Parallel(n_jobs=-1)]: Done 367 tasks      | elapsed:   36.6s
# [Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed:   36.7s
# [Parallel(n_jobs=-1)]: Done 369 tasks      | elapsed:   36.7s
# [Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed:   36.8s
# [Parallel(n_jobs=-1)]: Done 371 tasks      | elapsed:   36.9s
# [Parallel(n_jobs=-1)]: Done 372 tasks      | elapsed:   36.9s
# [Parallel(n_jobs=-1)]: Done 373 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=-1)]: Done 374 tasks      | elapsed:   37.2s
# [Parallel(n_jobs=-1)]: Done 375 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=-1)]: Done 377 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done 378 tasks      | elapsed:   37.5s
# [Parallel(n_jobs=-1)]: Done 379 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:   37.7s
# [Parallel(n_jobs=-1)]: Done 382 tasks      | elapsed:   37.7s
# [Parallel(n_jobs=-1)]: Done 383 tasks      | elapsed:   37.8s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:   37.8s
# [Parallel(n_jobs=-1)]: Done 385 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=-1)]: Done 387 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=-1)]: Done 388 tasks      | elapsed:   38.3s
# [Parallel(n_jobs=-1)]: Done 389 tasks      | elapsed:   38.3s
# [Parallel(n_jobs=-1)]: Done 390 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=-1)]: Done 391 tasks      | elapsed:   38.5s
# [Parallel(n_jobs=-1)]: Done 392 tasks      | elapsed:   38.6s
# [Parallel(n_jobs=-1)]: Done 393 tasks      | elapsed:   38.6s
# [Parallel(n_jobs=-1)]: Done 394 tasks      | elapsed:   38.7s
# [Parallel(n_jobs=-1)]: Done 395 tasks      | elapsed:   38.7s
# [Parallel(n_jobs=-1)]: Done 396 tasks      | elapsed:   38.8s
# [Parallel(n_jobs=-1)]: Done 397 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=-1)]: Done 398 tasks      | elapsed:   39.1s
# [Parallel(n_jobs=-1)]: Done 399 tasks      | elapsed:   39.1s
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=-1)]: Done 401 tasks      | elapsed:   39.4s
# [Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=-1)]: Done 403 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=-1)]: Done 404 tasks      | elapsed:   39.6s
# [Parallel(n_jobs=-1)]: Done 405 tasks      | elapsed:   39.6s
# [Parallel(n_jobs=-1)]: Done 406 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done 407 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=-1)]: Done 408 tasks      | elapsed:   39.9s
# [Parallel(n_jobs=-1)]: Done 409 tasks      | elapsed:   39.9s
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=-1)]: Done 411 tasks      | elapsed:   40.1s
# [Parallel(n_jobs=-1)]: Done 412 tasks      | elapsed:   40.2s
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:   40.3s
# [Parallel(n_jobs=-1)]: Done 414 tasks      | elapsed:   40.4s
# [Parallel(n_jobs=-1)]: Done 415 tasks      | elapsed:   40.4s
# [Parallel(n_jobs=-1)]: Done 416 tasks      | elapsed:   40.5s
# [Parallel(n_jobs=-1)]: Done 417 tasks      | elapsed:   40.5s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   40.6s
# [Parallel(n_jobs=-1)]: Done 419 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=-1)]: Done 420 tasks      | elapsed:   40.8s
# [Parallel(n_jobs=-1)]: Done 421 tasks      | elapsed:   40.8s
# [Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=-1)]: Done 423 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=-1)]: Done 424 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=-1)]: Done 425 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:   41.4s
# [Parallel(n_jobs=-1)]: Done 427 tasks      | elapsed:   41.4s
# [Parallel(n_jobs=-1)]: Done 428 tasks      | elapsed:   41.5s
# [Parallel(n_jobs=-1)]: Done 429 tasks      | elapsed:   41.6s
# [Parallel(n_jobs=-1)]: Done 430 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done 431 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done 432 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=-1)]: Done 433 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   41.9s
# [Parallel(n_jobs=-1)]: Done 435 tasks      | elapsed:   42.0s
# [Parallel(n_jobs=-1)]: Done 436 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=-1)]: Done 437 tasks      | elapsed:   42.2s
# [Parallel(n_jobs=-1)]: Done 438 tasks      | elapsed:   42.3s
# [Parallel(n_jobs=-1)]: Done 439 tasks      | elapsed:   42.3s
# [Parallel(n_jobs=-1)]: Done 440 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=-1)]: Done 443 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=-1)]: Done 445 tasks      | elapsed:   42.8s
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=-1)]: Done 447 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=-1)]: Done 448 tasks      | elapsed:   43.1s
# [Parallel(n_jobs=-1)]: Done 449 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=-1)]: Done 451 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=-1)]: Done 452 tasks      | elapsed:   43.4s
# [Parallel(n_jobs=-1)]: Done 453 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=-1)]: Done 454 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=-1)]: Done 455 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed:   43.7s
# [Parallel(n_jobs=-1)]: Done 457 tasks      | elapsed:   43.7s
# [Parallel(n_jobs=-1)]: Done 458 tasks      | elapsed:   43.8s
# [Parallel(n_jobs=-1)]: Done 459 tasks      | elapsed:   43.8s
# [Parallel(n_jobs=-1)]: Done 460 tasks      | elapsed:   44.0s
# [Parallel(n_jobs=-1)]: Done 461 tasks      | elapsed:   44.0s
# [Parallel(n_jobs=-1)]: Done 462 tasks      | elapsed:   44.2s
# [Parallel(n_jobs=-1)]: Done 463 tasks      | elapsed:   44.2s
# [Parallel(n_jobs=-1)]: Done 464 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=-1)]: Done 465 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=-1)]: Done 466 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=-1)]: Done 467 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=-1)]: Done 468 tasks      | elapsed:   44.6s
# [Parallel(n_jobs=-1)]: Done 469 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=-1)]: Done 470 tasks      | elapsed:   44.8s
# [Parallel(n_jobs=-1)]: Done 471 tasks      | elapsed:   44.8s
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed:   45.0s
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:   45.0s
# [Parallel(n_jobs=-1)]: Done 474 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=-1)]: Done 475 tasks      | elapsed:   45.2s
# [Parallel(n_jobs=-1)]: Done 476 tasks      | elapsed:   45.3s
# [Parallel(n_jobs=-1)]: Done 477 tasks      | elapsed:   45.3s
# [Parallel(n_jobs=-1)]: Done 478 tasks      | elapsed:   45.5s
# [Parallel(n_jobs=-1)]: Done 479 tasks      | elapsed:   45.5s
# [Parallel(n_jobs=-1)]: Done 480 tasks      | elapsed:   45.6s
# [Parallel(n_jobs=-1)]: Done 481 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=-1)]: Done 482 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=-1)]: Done 483 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=-1)]: Done 484 tasks      | elapsed:   45.9s
# [Parallel(n_jobs=-1)]: Done 485 tasks      | elapsed:   46.0s
# [Parallel(n_jobs=-1)]: Done 486 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=-1)]: Done 487 tasks      | elapsed:   46.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   46.3s
# [Parallel(n_jobs=-1)]: Done 489 tasks      | elapsed:   46.3s
# [Parallel(n_jobs=-1)]: Done 490 tasks      | elapsed:   46.5s
# [Parallel(n_jobs=-1)]: Done 491 tasks      | elapsed:   46.5s
# [Parallel(n_jobs=-1)]: Done 492 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=-1)]: Done 493 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=-1)]: Done 494 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=-1)]: Done 495 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed:   46.9s
# [Parallel(n_jobs=-1)]: Done 497 tasks      | elapsed:   46.9s
# [Parallel(n_jobs=-1)]: Done 498 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=-1)]: Done 499 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=-1)]: Done 500 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done 501 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done 502 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=-1)]: Done 503 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=-1)]: Done 505 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=-1)]: Done 506 tasks      | elapsed:   47.7s
# [Parallel(n_jobs=-1)]: Done 507 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done 508 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done 509 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done 510 tasks      | elapsed:   48.1s
# [Parallel(n_jobs=-1)]: Done 511 tasks      | elapsed:   48.1s
# [Parallel(n_jobs=-1)]: Done 512 tasks      | elapsed:   48.3s
# [Parallel(n_jobs=-1)]: Done 513 tasks      | elapsed:   48.3s
# [Parallel(n_jobs=-1)]: Done 514 tasks      | elapsed:   48.4s
# [Parallel(n_jobs=-1)]: Done 515 tasks      | elapsed:   48.5s
# [Parallel(n_jobs=-1)]: Done 516 tasks      | elapsed:   48.5s
# [Parallel(n_jobs=-1)]: Done 517 tasks      | elapsed:   48.6s
# [Parallel(n_jobs=-1)]: Done 518 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=-1)]: Done 519 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done 520 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done 521 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=-1)]: Done 522 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=-1)]: Done 523 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=-1)]: Done 524 tasks      | elapsed:   49.3s
# [Parallel(n_jobs=-1)]: Done 525 tasks      | elapsed:   49.3s
# [Parallel(n_jobs=-1)]: Done 526 tasks      | elapsed:   49.4s
# [Parallel(n_jobs=-1)]: Done 527 tasks      | elapsed:   49.4s
# [Parallel(n_jobs=-1)]: Done 528 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=-1)]: Done 529 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=-1)]: Done 530 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=-1)]: Done 531 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=-1)]: Done 532 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=-1)]: Done 533 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=-1)]: Done 534 tasks      | elapsed:   50.0s
# [Parallel(n_jobs=-1)]: Done 535 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done 536 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:   50.3s
# [Parallel(n_jobs=-1)]: Done 538 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=-1)]: Done 539 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=-1)]: Done 540 tasks      | elapsed:   50.6s
# [Parallel(n_jobs=-1)]: Done 541 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=-1)]: Done 542 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=-1)]: Done 543 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=-1)]: Done 544 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=-1)]: Done 545 tasks      | elapsed:   50.9s
# [Parallel(n_jobs=-1)]: Done 546 tasks      | elapsed:   51.0s
# [Parallel(n_jobs=-1)]: Done 547 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=-1)]: Done 548 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 549 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=-1)]: Done 550 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=-1)]: Done 551 tasks      | elapsed:   51.5s
# [Parallel(n_jobs=-1)]: Done 552 tasks      | elapsed:   51.5s
# [Parallel(n_jobs=-1)]: Done 553 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=-1)]: Done 554 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=-1)]: Done 555 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=-1)]: Done 556 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done 557 tasks      | elapsed:   51.9s
# [Parallel(n_jobs=-1)]: Done 558 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=-1)]: Done 559 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=-1)]: Done 560 tasks      | elapsed:   52.2s
# [Parallel(n_jobs=-1)]: Done 561 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=-1)]: Done 562 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=-1)]: Done 563 tasks      | elapsed:   52.4s
# [Parallel(n_jobs=-1)]: Done 564 tasks      | elapsed:   52.5s
# [Parallel(n_jobs=-1)]: Done 565 tasks      | elapsed:   52.5s
# [Parallel(n_jobs=-1)]: Done 566 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=-1)]: Done 567 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 569 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:   52.9s
# [Parallel(n_jobs=-1)]: Done 571 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=-1)]: Done 572 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=-1)]: Done 573 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 574 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 575 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 576 tasks      | elapsed:   53.5s
# [Parallel(n_jobs=-1)]: Done 577 tasks      | elapsed:   53.5s
# [Parallel(n_jobs=-1)]: Done 578 tasks      | elapsed:   53.6s
# [Parallel(n_jobs=-1)]: Done 579 tasks      | elapsed:   53.6s
# [Parallel(n_jobs=-1)]: Done 580 tasks      | elapsed:   53.7s
# [Parallel(n_jobs=-1)]: Done 581 tasks      | elapsed:   53.7s
# [Parallel(n_jobs=-1)]: Done 582 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=-1)]: Done 583 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done 585 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done 586 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done 587 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done 588 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=-1)]: Done 589 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=-1)]: Done 590 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=-1)]: Done 591 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=-1)]: Done 592 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=-1)]: Done 593 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=-1)]: Done 594 tasks      | elapsed:   54.9s
# [Parallel(n_jobs=-1)]: Done 595 tasks      | elapsed:   55.0s
# [Parallel(n_jobs=-1)]: Done 596 tasks      | elapsed:   55.1s
# [Parallel(n_jobs=-1)]: Done 597 tasks      | elapsed:   55.2s
# [Parallel(n_jobs=-1)]: Done 598 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=-1)]: Done 599 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=-1)]: Done 600 tasks      | elapsed:   55.4s
# [Parallel(n_jobs=-1)]: Done 601 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=-1)]: Done 602 tasks      | elapsed:   55.6s
# [Parallel(n_jobs=-1)]: Done 603 tasks      | elapsed:   55.7s
# [Parallel(n_jobs=-1)]: Done 604 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:   55.9s
# [Parallel(n_jobs=-1)]: Done 606 tasks      | elapsed:   55.9s
# [Parallel(n_jobs=-1)]: Done 607 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=-1)]: Done 608 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=-1)]: Done 609 tasks      | elapsed:   56.3s
# [Parallel(n_jobs=-1)]: Done 610 tasks      | elapsed:   56.4s
# [Parallel(n_jobs=-1)]: Done 611 tasks      | elapsed:   56.5s
# [Parallel(n_jobs=-1)]: Done 612 tasks      | elapsed:   56.5s
# [Parallel(n_jobs=-1)]: Done 613 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=-1)]: Done 614 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=-1)]: Done 615 tasks      | elapsed:   56.7s
# [Parallel(n_jobs=-1)]: Done 616 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=-1)]: Done 617 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=-1)]: Done 618 tasks      | elapsed:   57.0s
# [Parallel(n_jobs=-1)]: Done 619 tasks      | elapsed:   57.2s
# [Parallel(n_jobs=-1)]: Done 620 tasks      | elapsed:   57.2s
# [Parallel(n_jobs=-1)]: Done 621 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=-1)]: Done 622 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=-1)]: Done 623 tasks      | elapsed:   57.5s
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:   57.6s
# [Parallel(n_jobs=-1)]: Done 625 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=-1)]: Done 626 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=-1)]: Done 627 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=-1)]: Done 628 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=-1)]: Done 629 tasks      | elapsed:   57.9s
# [Parallel(n_jobs=-1)]: Done 630 tasks      | elapsed:   58.0s
# [Parallel(n_jobs=-1)]: Done 631 tasks      | elapsed:   58.2s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:   58.2s
# [Parallel(n_jobs=-1)]: Done 633 tasks      | elapsed:   58.3s
# [Parallel(n_jobs=-1)]: Done 634 tasks      | elapsed:   58.3s
# [Parallel(n_jobs=-1)]: Done 635 tasks      | elapsed:   58.5s
# [Parallel(n_jobs=-1)]: Done 636 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=-1)]: Done 637 tasks      | elapsed:   58.7s
# [Parallel(n_jobs=-1)]: Done 638 tasks      | elapsed:   58.7s
# [Parallel(n_jobs=-1)]: Done 639 tasks      | elapsed:   58.8s
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:   58.8s
# [Parallel(n_jobs=-1)]: Done 641 tasks      | elapsed:   59.0s
# [Parallel(n_jobs=-1)]: Done 642 tasks      | elapsed:   59.0s
# [Parallel(n_jobs=-1)]: Done 643 tasks      | elapsed:   59.2s
# [Parallel(n_jobs=-1)]: Done 644 tasks      | elapsed:   59.3s
# [Parallel(n_jobs=-1)]: Done 645 tasks      | elapsed:   59.4s
# [Parallel(n_jobs=-1)]: Done 646 tasks      | elapsed:   59.4s
# [Parallel(n_jobs=-1)]: Done 647 tasks      | elapsed:   59.5s
# [Parallel(n_jobs=-1)]: Done 648 tasks      | elapsed:   59.6s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:   59.6s
# [Parallel(n_jobs=-1)]: Done 650 tasks      | elapsed:   59.7s
# [Parallel(n_jobs=-1)]: Done 651 tasks      | elapsed:   59.7s
# [Parallel(n_jobs=-1)]: Done 652 tasks      | elapsed:   59.8s
# [Parallel(n_jobs=-1)]: Done 653 tasks      | elapsed:   60.0s
# [Parallel(n_jobs=-1)]: Done 654 tasks      | elapsed:   60.0s
# [Parallel(n_jobs=-1)]: Done 655 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 656 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 657 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 658 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 659 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 660 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 661 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 662 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 663 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 664 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 665 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 666 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 667 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 668 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 669 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 670 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 671 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 672 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 673 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 674 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 675 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 676 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 678 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 679 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 680 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 681 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 682 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 683 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 684 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 685 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 686 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 687 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 688 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 689 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 690 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 691 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 692 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 693 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 694 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 695 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 697 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 698 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 699 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 700 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 701 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 702 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 703 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 704 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 705 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 706 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 707 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 708 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 709 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 710 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 711 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 712 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 713 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 715 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 716 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 717 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 718 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 719 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 720 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 721 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 722 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 723 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 724 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 725 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 726 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 727 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 728 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 729 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 730 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 731 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 732 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 733 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 734 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 735 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 745 out of 990 | elapsed:  1.1min remaining:   22.2s
# [Parallel(n_jobs=-1)]: Done 755 out of 990 | elapsed:  1.1min remaining:   21.3s
# [Parallel(n_jobs=-1)]: Done 765 out of 990 | elapsed:  1.2min remaining:   20.4s
# [Parallel(n_jobs=-1)]: Done 775 out of 990 | elapsed:  1.2min remaining:   19.5s
# [Parallel(n_jobs=-1)]: Done 785 out of 990 | elapsed:  1.2min remaining:   18.5s
# [Parallel(n_jobs=-1)]: Done 795 out of 990 | elapsed:  1.2min remaining:   17.7s
# [Parallel(n_jobs=-1)]: Done 805 out of 990 | elapsed:  1.2min remaining:   16.7s
# [Parallel(n_jobs=-1)]: Done 815 out of 990 | elapsed:  1.2min remaining:   15.8s
# [Parallel(n_jobs=-1)]: Done 825 out of 990 | elapsed:  1.2min remaining:   14.9s
# [Parallel(n_jobs=-1)]: Done 835 out of 990 | elapsed:  1.3min remaining:   14.0s
# [Parallel(n_jobs=-1)]: Done 845 out of 990 | elapsed:  1.3min remaining:   13.0s
# [Parallel(n_jobs=-1)]: Done 855 out of 990 | elapsed:  1.3min remaining:   12.1s
# [Parallel(n_jobs=-1)]: Done 865 out of 990 | elapsed:  1.3min remaining:   11.2s
# [Parallel(n_jobs=-1)]: Done 875 out of 990 | elapsed:  1.3min remaining:   10.3s
# [Parallel(n_jobs=-1)]: Done 885 out of 990 | elapsed:  1.3min remaining:    9.4s
# [Parallel(n_jobs=-1)]: Done 895 out of 990 | elapsed:  1.3min remaining:    8.5s
# [Parallel(n_jobs=-1)]: Done 905 out of 990 | elapsed:  1.4min remaining:    7.7s
# [Parallel(n_jobs=-1)]: Done 915 out of 990 | elapsed:  1.4min remaining:    6.8s
# [Parallel(n_jobs=-1)]: Done 925 out of 990 | elapsed:  1.4min remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done 935 out of 990 | elapsed:  1.4min remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done 945 out of 990 | elapsed:  1.4min remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done 955 out of 990 | elapsed:  1.4min remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done 965 out of 990 | elapsed:  1.4min remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 975 out of 990 | elapsed:  1.5min remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 985 out of 990 | elapsed:  1.5min remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 990 out of 990 | elapsed:  1.5min finished
# [Pipeline] .... (step 1 of 2) Processing standardscaler, total=   0.0s
# [Pipeline]  (step 2 of 2) Processing kneighborsclassifier, total=   0.0s
# GridSearchCV(cv=10, error_score='raise',
#              estimator=Pipeline(steps=[('standardscaler',
#                                         StandardScaler(with_mean=False)),
#                                        ('kneighborsclassifier',
#                                         KNeighborsClassifier(n_jobs=-1, p=1,
#                                                              weights='distance'))],
#                                 verbose=True),
#              n_jobs=-1,
#              param_grid={'kneighborsclassifier__n_neighbors': range(3, 200, 2)},
#              pre_dispatch=256, refit='recall_weighted',
#              scoring=['recall_weighted'], verbose=100)

# %%
print('Completed grid search in %f seconds' % (elapsed_time(t0)))
# Out:
# Completed grid search in 89.292843 seconds

# %%
# Store best KNeighborsClassifier from GridSearchCV and print its parameters.
k_neighbors_clf = grid_search_cv.best_estimator_
print('Best KNeighborsClassifier parameters:')
for key in k_neighbors_clf.get_params().keys():
    print(key, ':', k_neighbors_clf.get_params()[key])
# Out:
# Best KNeighborsClassifier parameters:
# memory : None
# steps : [('standardscaler', StandardScaler(with_mean=False)), ('kneighborsclassifier', KNeighborsClassifier(n_jobs=-1, n_neighbors=39, p=1, weights='distance'))]
# verbose : True
# standardscaler : StandardScaler(with_mean=False)
# kneighborsclassifier : KNeighborsClassifier(n_jobs=-1, n_neighbors=39, p=1, weights='distance')
# standardscaler__copy : True
# standardscaler__with_mean : False
# standardscaler__with_std : True
# kneighborsclassifier__algorithm : auto
# kneighborsclassifier__leaf_size : 30
# kneighborsclassifier__metric : minkowski
# kneighborsclassifier__metric_params : None
# kneighborsclassifier__n_jobs : -1
# kneighborsclassifier__n_neighbors : 39
# kneighborsclassifier__p : 1
# kneighborsclassifier__weights : distance

# %%
t0 = default_timer()
number_of_folds = 10
#kfold_cv = StratifiedKFold(n_splits=number_of_folds, shuffle=True, random_state=seed)
scoring = ['f1_macro', 'f1_weighted', 'neg_log_loss', 'precision_macro', 'precision_weighted', 'recall_macro', 'recall_weighted']
k_neighbors_scores = cross_validate(k_neighbors_clf, X, y, scoring=scoring, n_jobs=-1, cv=number_of_folds, return_estimator=True)
print("k-Neighbors score keys:", sorted(k_neighbors_scores.keys()))
print('k-Neighbors Classifiers constructed in %f seconds.' % elapsed_time(t0))
# Out:
# k-Neighbors score keys: ['estimator', 'fit_time', 'score_time', 'test_f1_macro', 'test_f1_weighted', 'test_neg_log_loss', 'test_precision_macro', 'test_precision_weighted', 'test_recall_macro', 'test_recall_weighted']
# k-Neighbors Classifiers constructed in 6.980404 seconds.

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 130.09596840909217 seconds.

# %% [markdown]
# ## Validate of the Models

# %%
# Set starting time for reports and graphics.
t0 = default_timer()

# %%
#df_categorical.info()
df_validate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171216 entries, 105805 to 212733
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SEVERITYCODE     171216 non-null  category
#  1   COLLISIONTYPE    171216 non-null  category
#  2   PERSONCOUNT      171216 non-null  int64
#  3   PEDCOUNT         171216 non-null  int64
#  4   PEDCYLCOUNT      171216 non-null  int64
#  5   VEHCOUNT         171216 non-null  int64
#  6   INJURIES         171216 non-null  int64
#  7   SERIOUSINJURIES  171216 non-null  int64
#  8   FATALITIES       171216 non-null  int64
#  9   WEATHER          171216 non-null  category
#  10  ROADCOND         171216 non-null  category
#  11  LIGHTCOND        171216 non-null  category
# dtypes: category(5), int64(7)
# memory usage: 11.3 MB

# %%
# Print the relative frequencies for the validation DataFrame.
print("SEVERITYCODE relative frequencies:")
print(df_validate["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 1     112918
# 2      55357
# 2b      2777
# 3        164
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
# Print the relative frequencies for the validation DataFrame.
print("SEVERITYCODE relative frequencies:")
print(df_validate["SEVERITYCODE"].value_counts(normalize=True, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 1    0.659506121
# 2    0.323316746
# 2b   0.016219279
# 3    0.000957854
# Name: SEVERITYCODE, Length: 4, dtype: float64

# %%
# Encode the data using the OneHotEncoder fitted before the models were created.
start_time = default_timer()
# print("Transforming full data set's feature set using OneHotEncoder...")
# X = df_categorical.drop(columns=['SEVERITYCODE', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES'], inplace=False)
# X = encoder.transform(X)
print('Transforming features using OneHotEncoder...')
X = df_validate.drop(columns=['SEVERITYCODE', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES'], inplace=False)
X = encoder.transform(X)
print("Completed in", elapsed_time(start_time), "seconds.")
# Out:
# Transforming features using OneHotEncoder...
# Completed in 1.0418606479652226 seconds.

# %%
y = df_validate['SEVERITYCODE'].to_numpy()

# %%
X.shape
# Out:
# (171216, 51)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=validation_ratio, random_state=seed, shuffle=True)

# %%
X_test.shape
# Out:
# (85608, 51)

# %%
# Report statistics of the models built for each fold of the cross-validation.
for key in sorted(logistic_regression_scores.keys()):
    if key != 'estimator':
        print('%s: mean = %f, std = %f' % (key, np.mean(logistic_regression_scores[key]), np.std(logistic_regression_scores[key])), sep='')
        print('%s :%s' % (key, logistic_regression_scores[key]), sep='')
        print()
# Out:
# fit_time: mean = 0.518669, std = 0.149080
# fit_time :[0.63218307 0.83250761 0.49637485 0.66606641 0.51908016 0.47406149
#  0.36780405 0.47722483 0.28238487 0.43900251]
#
# score_time: mean = 0.069904, std = 0.028230
# score_time :[0.09333611 0.04448962 0.11364007 0.11688066 0.03863072 0.06744409
#  0.04042029 0.08083487 0.05468464 0.04867911]
#
# test_f1_macro: mean = 0.431982, std = 0.062904
# test_f1_macro :[0.461833   0.53799081 0.45477314 0.44679487 0.34497338 0.44387772
#  0.47487208 0.3952381  0.45163345 0.30783331]
#
# test_f1_weighted: mean = 0.432286, std = 0.062653
# test_f1_weighted :[0.46274254 0.53902813 0.45288526 0.44246309 0.34565371 0.44330567
#  0.47809267 0.39684982 0.45214445 0.30969082]
#
# test_neg_log_loss: mean = -1.210722, std = 0.108159
# test_neg_log_loss :[-1.19843999 -1.01001462 -1.30053008 -1.24719171 -1.3488173  -1.20425979
#  -1.01206321 -1.24092025 -1.26835868 -1.27662222]
#
# test_precision_macro: mean = 0.450030, std = 0.073486
# test_precision_macro :[0.51235632 0.548583   0.4582967  0.48956961 0.34642857 0.47736264
#  0.5141369  0.39144737 0.45260377 0.30951486]
#
# test_precision_weighted: mean = 0.450301, std = 0.073126
# test_precision_weighted :[0.5102055  0.55005521 0.45781219 0.48542074 0.3475469  0.47988012
#  0.51575092 0.39271255 0.45333294 0.31029155]
#
# test_recall_macro: mean = 0.441728, std = 0.062624
# test_recall_macro :[0.48161765 0.54503676 0.47334559 0.44393382 0.34834559 0.45772059
#  0.47242647 0.41360294 0.46139706 0.31985294]
#
# test_recall_weighted: mean = 0.441935, std = 0.062183
# test_recall_weighted :[0.48484848 0.54545455 0.46969697 0.43939394 0.34848485 0.45454545
#  0.47692308 0.41538462 0.46153846 0.32307692]

# %%
# For each logistic regression classifier in the cross-validation, print the macro recall, score report, and confusion matrices.
number_of_models = len(logistic_regression_scores['estimator'])
labels = ['1', '2', '2b', '3']
for index, logistic_regression_clf in zip(range(len(logistic_regression_scores['estimator'])), logistic_regression_scores['estimator']):
    y_test_predicted = logistic_regression_clf.predict(X_test)
    logistic_regression_recall_score = recall_score(y_test, y_test_predicted, average='macro', labels=labels)
    print('Logistic Regression Model %d of %d:' % (index + 1, number_of_models))
    print()
    print(classification_report(y_test, y_test_predicted, labels=labels, target_names=labels, digits=6))
        
    # Create a figure.
    fig = plt.figure(num=str(index + 1), figsize=(6.4 * 3, 4.8))
    fig.suptitle('Confusion Matrices for Logistic Regression Model %d of %d:' % (index + 1, number_of_models), fontsize=20)
    
    ax = plt.subplot(1, 3, 1)
    ax.set_title("Normalized over Predicted Condition", fontsize=12)
    plot_confusion_matrix(logistic_regression_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='pred', ax=ax)
    
    ax = plt.subplot(1, 3, 2)
    ax.set_title("Normalized over True Conditions", fontsize=12)
    plot_confusion_matrix(logistic_regression_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='true', ax=ax)
    
    ax = plt.subplot(1, 3, 3)
    ax.set_title("Not Normalized", fontsize=12)
    plot_confusion_matrix(logistic_regression_clf, X_test, y_test, labels=labels, display_labels=labels, normalize=None, ax=ax)

    plt.show()
# Out:
# Logistic Regression Model 1 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.798510  0.607821  0.690237     56594
#            2   0.441386  0.364807  0.399460     27557
#           2b   0.029969  0.195636  0.051976      1375
#            3   0.003990  0.524390  0.007920        82
#
#     accuracy                       0.522895     85608
#    macro avg   0.318464  0.423164  0.287398     85608
# weighted avg   0.670447  0.522895  0.585731     85608
# Logistic Regression Model 2 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.798101  0.616408  0.695585     56594
#            2   0.437323  0.359038  0.394333     27557
#           2b   0.038095  0.282182  0.067128      1375
#            3   0.004181  0.463415  0.008287        82
#
#     accuracy                       0.528046     85608
#    macro avg   0.319425  0.430261  0.291333     85608
# weighted avg   0.669000  0.528046  0.587861     85608
# Logistic Regression Model 3 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.799337  0.617998  0.697067     56594
#            2   0.433737  0.348695  0.386595     27557
#           2b   0.032690  0.257455  0.058014      1375
#            3   0.004171  0.451220  0.008266        82
#
#     accuracy                       0.525360     85608
#    macro avg   0.317484  0.418842  0.287485     85608
# weighted avg   0.668576  0.525360  0.586203     85608
# Logistic Regression Model 4 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.799158  0.627222  0.702827     56594
#            2   0.444058  0.384839  0.412333     27557
#           2b   0.040205  0.274182  0.070126      1375
#            3   0.004161  0.402439  0.008237        82
#
#     accuracy                       0.543314     85608
#    macro avg   0.321895  0.422170  0.298381     85608
# weighted avg   0.671901  0.543314  0.598490     85608
# Logistic Regression Model 5 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.793063  0.618122  0.694749     56594
#            2   0.427612  0.385746  0.405601     27557
#           2b   0.039827  0.201455  0.066507      1375
#            3   0.003924  0.463415  0.007782        82
#
#     accuracy                       0.536480     85608
#    macro avg   0.316106  0.417184  0.293660     85608
# weighted avg   0.662571  0.536480  0.590924     85608
# Logistic Regression Model 6 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.799948  0.593367  0.681343     56594
#            2   0.419387  0.408825  0.414039     27557
#           2b   0.044108  0.248000  0.074896      1375
#            3   0.003874  0.426829  0.007678        82
#
#     accuracy                       0.528257     85608
#    macro avg   0.316829  0.419255  0.294489     85608
# weighted avg   0.664544  0.528257  0.584913     85608
# Logistic Regression Model 7 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.790845  0.639856  0.707383     56594
#            2   0.441288  0.333708  0.380031     27557
#           2b   0.038265  0.310545  0.068135      1375
#            3   0.004347  0.414634  0.008604        82
#
#     accuracy                       0.535803     85608
#    macro avg   0.318686  0.424686  0.291038     85608
# weighted avg   0.665482  0.535803  0.591073     85608
# Logistic Regression Model 8 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.793894  0.615277  0.693266     56594
#            2   0.425334  0.380049  0.401418     27557
#           2b   0.042627  0.267636  0.073541      1375
#            3   0.004122  0.426829  0.008165        82
#
#     accuracy                       0.533794     85608
#    macro avg   0.316494  0.422448  0.294098     85608
# weighted avg   0.662433  0.533794  0.588711     85608
# Logistic Regression Model 9 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.797940  0.613139  0.693438     56594
#            2   0.423883  0.347280  0.381777     27557
#           2b   0.035424  0.244364  0.061878      1375
#            3   0.004175  0.512195  0.008283        82
#
#     accuracy                       0.521540     85608
#    macro avg   0.315356  0.429245  0.286344     85608
# weighted avg   0.664524  0.521540  0.582315     85608
# Logistic Regression Model 10 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.800809  0.587412  0.677709     56594
#            2   0.428278  0.355155  0.388304     27557
#           2b   0.030852  0.250182  0.054930      1375
#            3   0.003864  0.475610  0.007666        82
#
#     accuracy                       0.507126     85608
#    macro avg   0.315951  0.417090  0.282152     85608
# weighted avg   0.667762  0.507126  0.573906     85608

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 303.9749362959992 seconds.

# %%
# Report statistics of the models built for each fold of the cross-validation.
for key in sorted(linear_svc_scores.keys()):
    if key != 'estimator':
        print('%s: mean = %f, std = %f' % (key, np.mean(linear_svc_scores[key]), np.std(linear_svc_scores[key])), sep='')
        print('%s :%s' % (key, linear_svc_scores[key]), sep='')
        print()
# Out:
# fit_time: mean = 0.091816, std = 0.021550
# fit_time :[0.11120677 0.09854078 0.06399012 0.10731292 0.06325269 0.12160778
#  0.05656767 0.10757303 0.09263158 0.09547329]
#
# score_time: mean = 0.070621, std = 0.020994
# score_time :[0.08693838 0.09256172 0.05354905 0.0926373  0.04150343 0.05852461
#  0.03779936 0.0769639  0.09822869 0.06750393]
#
# test_f1_macro: mean = 0.426099, std = 0.057254
# test_f1_macro :[0.44334818 0.51931142 0.41805556 0.43429487 0.38711068 0.44561089
#  0.49831081 0.34059911 0.44287521 0.33146853]
#
# test_f1_weighted: mean = 0.426190, std = 0.057050
# test_f1_weighted :[0.4439769  0.52066452 0.41481481 0.4295843  0.38713554 0.44395326
#  0.5014553  0.34264658 0.44309472 0.33457414]
#
# test_precision_macro: mean = 0.447528, std = 0.084948
# test_precision_macro :[0.58333333 0.52998252 0.41790655 0.46259176 0.39375    0.48177258
#  0.53154762 0.30753968 0.44206349 0.32478992]
#
# test_precision_weighted: mean = 0.447577, std = 0.083946
# test_precision_weighted :[0.57828283 0.53157978 0.41678117 0.45919956 0.39494949 0.48372352
#  0.53336996 0.30940171 0.44210012 0.32638655]
#
# test_recall_macro: mean = 0.445129, std = 0.049874
# test_recall_macro :[0.46691176 0.52941176 0.44485294 0.44485294 0.39522059 0.47426471
#  0.50367647 0.38235294 0.44577206 0.36397059]
#
# test_recall_weighted: mean = 0.445012, std = 0.049483
# test_recall_weighted :[0.46969697 0.53030303 0.43939394 0.43939394 0.39393939 0.46969697
#  0.50769231 0.38461538 0.44615385 0.36923077]

# %%
# For each support vector machine classifier in the cross-validation, print the macro recall, score report, and confusion matrices.
number_of_models = len(linear_svc_scores['estimator'])
labels = ['1', '2', '2b', '3']
for index, linear_svc_clf in zip(range(len(linear_svc_scores['estimator'])), linear_svc_scores['estimator']):
    y_test_predicted = linear_svc_clf.predict(X_test)
    linear_svc_recall_score = recall_score(y_test, y_test_predicted, average='macro', labels=labels)
    print('Support Vector Machine Model %d of %d:' % (index + 1, number_of_models))
    print()
    print(classification_report(y_test, y_test_predicted, labels=labels, target_names=labels, digits=6))
        
    # Create a figure.
    fig = plt.figure(num=str(index + 1), figsize=(6.4 * 3, 4.8))
    fig.suptitle('Confusion Matrices for Support Vector Machine Model %d of %d:' % (index + 1, number_of_models), fontsize=20)
    
    ax = plt.subplot(1,3,1)
    ax.set_title("Normalized over Predicted Condition", fontsize=12)
    plot_confusion_matrix(linear_svc_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='pred', ax=ax)
    
    ax = plt.subplot(1,3,2)
    ax.set_title("Normalized over True Conditions", fontsize=12)
    plot_confusion_matrix(linear_svc_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='true', ax=ax)
    
    ax = plt.subplot(1,3,3)
    ax.set_title("Not Normalized", fontsize=12)
    plot_confusion_matrix(linear_svc_clf, X_test, y_test, labels=labels, display_labels=labels, normalize=None, ax=ax)
    
    plt.show()
# Out:
# Support Vector Machine Model 1 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.799815  0.626338  0.702526     56594
#            2   0.451832  0.353159  0.396448     27557
#           2b   0.026524  0.160727  0.045534      1375
#            3   0.004204  0.585366  0.008348        82
#
#     accuracy                       0.530885     85608
#    macro avg   0.320594  0.431398  0.288214     85608
# weighted avg   0.674618  0.530885  0.592783     85608
# Support Vector Machine Model 2 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.801097  0.613952  0.695149     56594
#            2   0.437624  0.351344  0.389767     27557
#           2b   0.035348  0.265455  0.062388      1375
#            3   0.004088  0.487805  0.008108        82
#
#     accuracy                       0.523701     85608
#    macro avg   0.319539  0.429639  0.288853     85608
# weighted avg   0.671034  0.523701  0.586026     85608
# Support Vector Machine Model 3 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.804807  0.611249  0.694799     56594
#            2   0.446055  0.338462  0.384880     27557
#           2b   0.029127  0.221091  0.051473      1375
#            3   0.003990  0.548780  0.007923        82
#
#     accuracy                       0.517113     85608
#    macro avg   0.320995  0.429896  0.284769     85608
# weighted avg   0.676099  0.517113  0.584046     85608
# Support Vector Machine Model 4 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.801767  0.631763  0.706685     56594
#            2   0.445688  0.375803  0.407773     27557
#           2b   0.037057  0.248727  0.064504      1375
#            3   0.004211  0.439024  0.008342        82
#
#     accuracy                       0.543033     85608
#    macro avg   0.322181  0.423829  0.296826     85608
# weighted avg   0.674100  0.543033  0.599482     85608
# Support Vector Machine Model 5 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.799238  0.608262  0.690794     56594
#            2   0.428372  0.401277  0.414382     27557
#           2b   0.033008  0.147636  0.053953      1375
#            3   0.004445  0.573171  0.008822        82
#
#     accuracy                       0.534202     85608
#    macro avg   0.316266  0.432587  0.291988     85608
# weighted avg   0.666789  0.534202  0.590936     85608
# Support Vector Machine Model 6 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.798901  0.629519  0.704167     56594
#            2   0.436127  0.390500  0.412054     27557
#           2b   0.043869  0.205818  0.072323      1375
#            3   0.004045  0.487805  0.008024        82
#
#     accuracy                       0.545638     85608
#    macro avg   0.320736  0.428410  0.299142     85608
# weighted avg   0.669237  0.545638  0.599322     85608
# Support Vector Machine Model 7 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.799916  0.636552  0.708944     56594
#            2   0.446614  0.335305  0.383037     27557
#           2b   0.035921  0.288727  0.063893      1375
#            3   0.004416  0.475610  0.008751        82
#
#     accuracy                       0.533840     85608
#    macro avg   0.321717  0.434048  0.291156     85608
# weighted avg   0.673156  0.533840  0.593004     85608
# Support Vector Machine Model 8 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.793239  0.628547  0.701355     56594
#            2   0.427022  0.370106  0.396532     27557
#           2b   0.041614  0.213818  0.069668      1375
#            3   0.004381  0.524390  0.008690        82
#
#     accuracy                       0.538595     85608
#    macro avg   0.316564  0.434215  0.294061     85608
# weighted avg   0.662527  0.538595  0.592424     85608
# Support Vector Machine Model 9 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.802546  0.610524  0.693488     56594
#            2   0.431685  0.347171  0.384843     27557
#           2b   0.031147  0.218909  0.054534      1375
#            3   0.004287  0.560976  0.008510        82
#
#     accuracy                       0.519414     85608
#    macro avg   0.317416  0.434395  0.285344     85608
# weighted avg   0.670012  0.519414  0.583217     85608
# Support Vector Machine Model 10 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.802989  0.602873  0.688688     56594
#            2   0.433816  0.349893  0.387361     27557
#           2b   0.031092  0.228364  0.054732      1375
#            3   0.004169  0.548780  0.008276        82
#
#     accuracy                       0.515372     85608
#    macro avg   0.318017  0.432478  0.284764     85608
# weighted avg   0.670990  0.515372  0.580858     85608

# %%
# Report statistics of the models built for each fold of the cross-validation.
for key in sorted(k_neighbors_scores.keys()):
    if key != 'estimator':
        print('%s: mean = %f, std = %f' % (key, np.mean(k_neighbors_scores[key]), np.std(k_neighbors_scores[key])), sep='')
        print('%s :%s' % (key, k_neighbors_scores[key]), sep='')
        print()
# Out:
# fit_time: mean = 0.025132, std = 0.012811
# fit_time :[0.04772115 0.04042435 0.01575398 0.0143652  0.01307225 0.01418161
#  0.01973248 0.03336263 0.01354456 0.03915834]
#
# score_time: mean = 0.224168, std = 0.049863
# score_time :[0.18115711 0.19951844 0.33822846 0.19678879 0.29066157 0.18458652
#  0.22644329 0.24188066 0.20034218 0.18207312]
#
# test_f1_macro: mean = 0.427311, std = 0.050672
# test_f1_macro :[0.44015322 0.54643875 0.41963723 0.36157407 0.38317736 0.40981199
#  0.4860828  0.40252013 0.42019525 0.40351459]
#
# test_f1_weighted: mean = 0.427523, std = 0.051732
# test_f1_weighted :[0.44104407 0.54806181 0.41724643 0.36015713 0.38248393 0.40892177
#  0.48964997 0.40298032 0.41968604 0.40499898]
#
# test_neg_log_loss: mean = -5.752026, std = 1.186844
# test_neg_log_loss :[-6.53414226 -5.41934469 -4.62875157 -8.09229961 -5.10087854 -6.68801069
#  -3.50123444 -5.70020282 -6.23950676 -5.61588536]
#
# test_precision_macro: mean = 0.443083, std = 0.045325
# test_precision_macro :[0.47012987 0.55581204 0.42765568 0.41278358 0.40336134 0.43925439
#  0.47784091 0.41596061 0.4330267  0.39500968]
#
# test_precision_weighted: mean = 0.443618, std = 0.045885
# test_precision_weighted :[0.46951987 0.55786264 0.42705073 0.41112028 0.4047619  0.44069644
#  0.48027972 0.41571506 0.43295815 0.39622006]
#
# test_recall_macro: mean = 0.443934, std = 0.050620
# test_recall_macro :[0.453125   0.55974265 0.44393382 0.36580882 0.41176471 0.42647059
#  0.50275735 0.41452206 0.43198529 0.42922794]
#
# test_recall_weighted: mean = 0.443613, std = 0.051982
# test_recall_weighted :[0.45454545 0.56060606 0.43939394 0.36363636 0.40909091 0.42424242
#  0.50769231 0.41538462 0.43076923 0.43076923]

# %%
# For each k-Nearest Neighbor classifier in the cross-validation, print the macro recall, score report, and confusion matrices.
number_of_models = len(k_neighbors_scores['estimator'])
labels = ['1', '2', '2b', '3']
for index, knn_clf in zip(range(len(k_neighbors_scores['estimator'])), k_neighbors_scores['estimator']):
    y_test_predicted = knn_clf.predict(X_test)
    knn_recall_score = recall_score(y_test, y_test_predicted, average='macro', labels=labels)
    print('k-Nearest Neighbor Model %d of %d:' % (index + 1, number_of_models))
    print()
    print(classification_report(y_test, y_test_predicted, labels=labels, target_names=labels, digits=6))
        
    # Create a figure.
    fig = plt.figure(num=str(index + 1), figsize=(6.4 * 3, 4.8))
    fig.suptitle('Confusion Matrices for k-Nearest Neighbor Model %d of %d:' % (index + 1, number_of_models), fontsize=20)
    
    ax = plt.subplot(1, 3, 1)
    ax.set_title("Normalized over Predicted Condition", fontsize=12)
    plot_confusion_matrix(knn_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='pred', ax=ax)
    
    ax = plt.subplot(1, 3, 2)
    ax.set_title("Normalized over True Conditions", fontsize=12)
    plot_confusion_matrix(knn_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='true', ax=ax)
    
    ax = plt.subplot(1, 3, 3)
    ax.set_title("Not Normalized", fontsize=12)
    plot_confusion_matrix(knn_clf, X_test, y_test, labels=labels, display_labels=labels, normalize=None, ax=ax)

    plt.show()
# Out:
# k-Nearest Neighbor Model 1 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.769614  0.636128  0.696533     56594
#            2   0.401817  0.354647  0.376761     27557
#           2b   0.030214  0.141818  0.049815      1375
#            3   0.005463  0.536585  0.010816        82
#
#     accuracy                       0.537485     85608
#    macro avg   0.301777  0.417294  0.283481     85608
# weighted avg   0.638613  0.537485  0.582555     85608
# k-Nearest Neighbor Model 2 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.773626  0.639061  0.699934     56594
#            2   0.401024  0.340966  0.368565     27557
#           2b   0.045879  0.246545  0.077362      1375
#            3   0.004478  0.439024  0.008866        82
#
#     accuracy                       0.536609     85608
#    macro avg   0.306252  0.416399  0.288682     85608
# weighted avg   0.641261  0.536609  0.582606     85608
# k-Nearest Neighbor Model 3 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.778811  0.628812  0.695820     56594
#            2   0.402005  0.344921  0.371282     27557
#           2b   0.044244  0.257455  0.075512      1375
#            3   0.004354  0.439024  0.008622        82
#
#     accuracy                       0.531282     85608
#    macro avg   0.307354  0.417553  0.287809     85608
# weighted avg   0.644978  0.531282  0.580730     85608
# k-Nearest Neighbor Model 4 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.766657  0.681503  0.721577     56594
#            2   0.414470  0.305803  0.351939     27557
#           2b   0.048252  0.264000  0.081591      1375
#            3   0.004567  0.414634  0.009034        82
#
#     accuracy                       0.553605     85608
#    macro avg   0.308487  0.416485  0.291035     85608
# weighted avg   0.641020  0.553605  0.591630     85608
# k-Nearest Neighbor Model 5 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.770426  0.630986  0.693769     56594
#            2   0.405172  0.326922  0.361865     27557
#           2b   0.035391  0.159273  0.057914      1375
#            3   0.003969  0.524390  0.007878        82
#
#     accuracy                       0.525430     85608
#    macro avg   0.303739  0.410393  0.280356     85608
# weighted avg   0.640311  0.525430  0.576060     85608
# k-Nearest Neighbor Model 6 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.768062  0.629660  0.692009     56594
#            2   0.400476  0.348333  0.372589     27557
#           2b   0.046256  0.248000  0.077970      1375
#            3   0.004447  0.426829  0.008802        82
#
#     accuracy                       0.532777     85608
#    macro avg   0.304810  0.413206  0.287842     85608
# weighted avg   0.637412  0.532777  0.578671     85608
# k-Nearest Neighbor Model 7 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.770753  0.648850  0.704567     56594
#            2   0.401634  0.328265  0.361262     27557
#           2b   0.045233  0.242909  0.076264      1375
#            3   0.004592  0.451220  0.009091        82
#
#     accuracy                       0.538945     85608
#    macro avg   0.305553  0.417811  0.287796     85608
# weighted avg   0.639548  0.538945  0.583301     85608
# k-Nearest Neighbor Model 8 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.769415  0.617433  0.685096     56594
#            2   0.391801  0.338498  0.363205     27557
#           2b   0.046620  0.239273  0.078036      1375
#            3   0.003752  0.426829  0.007439        82
#
#     accuracy                       0.521388     85608
#    macro avg   0.302897  0.405508  0.283444     85608
# weighted avg   0.635520  0.521388  0.571081     85608
# k-Nearest Neighbor Model 9 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.775102  0.652278  0.708405     56594
#            2   0.391594  0.330987  0.358748     27557
#           2b   0.041835  0.180364  0.067917      1375
#            3   0.004679  0.500000  0.009272        82
#
#     accuracy                       0.541129     85608
#    macro avg   0.303303  0.415907  0.286086     85608
# weighted avg   0.639136  0.541129  0.584895     85608
# k-Nearest Neighbor Model 10 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.774125  0.649062  0.706098     56594
#            2   0.406740  0.350800  0.376705     27557
#           2b   0.038846  0.178182  0.063785      1375
#            3   0.004701  0.463415  0.009308        82
#
#     accuracy                       0.545311     85608
#    macro avg   0.306103  0.410365  0.288974     85608
# weighted avg   0.643318  0.545311  0.589083     85608

# %%
print('Reports and graphics generated in %f seconds' % (elapsed_time(t0)))
# Out:
# Reports and graphics generated in 989.463411 seconds

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 1119.7621523929993 seconds.
