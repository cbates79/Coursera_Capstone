# %% [markdown]
# <h1 id="title">Sampling at 0.5 x Minority Class Size, Testing on All the Data, Predicting Motor Vehicle Accident Severity in Seattle, Washington<\h1>

# %%
# Import packages and modules.
import io
import itertools
import matplotlib as mpl
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import os
import pandas as pd
import pylab as pl
import scipy
import scipy.optimize as opt
import seaborn as sns
import sklearn
import sys
import timeit
import warnings
from matplotlib.ticker import NullFormatter
from scipy import optimize
from scipy.optimize import curve_fit
from scipy.sparse import csr_matrix
from sklearn import linear_model
from sklearn import metrics
from sklearn import pipeline
from sklearn import preprocessing
from sklearn import svm
from sklearn import tree
from sklearn import utils
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import jaccard_score
from sklearn.metrics import log_loss
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.utils import resample
from sklearn.utils import shuffle
from sklearn.exceptions import ConvergenceWarning
from timeit import default_timer
# %matplotlib inline

# %%
warnings.filterwarnings("ignore", category=ConvergenceWarning,
                        module="sklearn")

# %%
# Define the starting time for this notebook. 
notebook_start_time = default_timer()

# %%
# This function computes the time elapsed in seconds from the 
# time represented by the first parameter (start_time)
# to the time represented by the second parameter (end_time)
# This function requires the os package to be imported.
def elapsed_time(start_time = notebook_start_time):
    return default_timer() - start_time

# %%
# This function prints the time elapsed in seconds from the 
# time represented by the first parameter (start_time)
# to the time represented by the second parameter (end_time)
# This function requires the os package to be imported.
def print_elapsed_time(start_time = notebook_start_time):
    print("Elapsed time is", elapsed_time(start_time), "seconds.")
    return None

# %%
# Create a list of display options.
list_of_display_options_fully_qualified_names = str(\
"pd.options.display.chop_threshold, pd.options.display.float_format, pd.options.display.max_info_columns, pd.options.display.notebook_repr_html, \
pd.options.display.colheader_justify, pd.options.display.html, pd.options.display.max_info_rows, pd.options.display.pprint_nest_depth, \
pd.options.display.column_space, pd.options.display.large_repr, pd.options.display.max_rows, pd.options.display.precision, \
pd.options.display.date_dayfirst, pd.options.display.latex, pd.options.display.max_seq_items, pd.options.display.show_dimensions, \
pd.options.display.date_yearfirst, pd.options.display.max_categories, pd.options.display.memory_usage, pd.options.display.unicode, \
pd.options.display.encoding, pd.options.display.max_columns, pd.options.display.min_rows, pd.options.display.width, \
pd.options.display.expand_frame_repr, pd.options.display.max_colwidth, pd.options.display.multi_sparse").split(sep=', ')

# Initialize an empty list to store all the short names for display options.
list_of_display_options_short_names = list()
# For each fully qualified option name,
# get the option's short name and add it to the list of short names.
for fully_qualified_option_name in list_of_display_options_fully_qualified_names:
    # Get short option name.
    short_option_name = fully_qualified_option_name.split(sep='.')[-1]
    
    # Add short option name to list of display option short names.
    list_of_display_options_short_names.append(short_option_name)

# Define dictionary of display option settings.
dict_of_display_option_settings_short_names=\
{"max_info_columns": 1000,\
"colheader_justify": "right",\
"max_info_rows": 1000000,\
"column_space": 1000,\
"max_rows": 1000000,\
"precision": 9,\
"max_seq_items": 1000000000000,\
"show_dimensions": True,\
"max_categories": 100,\
"memory_usage": True,\
"max_columns": 1000,\
"max_colwidth": 1000,\
"float_format": lambda x: '%.9f' % x}

# Set pandas display options using dictionary of short names,
# and display the options/value pairs.
print("Setting display options...")
for key in list(dict_of_display_option_settings_short_names.keys()):
    # Set display option.
    pd.set_option(key, dict_of_display_option_settings_short_names[key])
    # Print display option name and value.
    print(key, ": ", pd.get_option(key), sep='')
# Out:
# Setting display options...
# max_info_columns: 1000
# colheader_justify: right
# max_info_rows: 1000000
# column_space: 1000
# max_rows: 1000000
# precision: 9
# max_seq_items: 1000000000000
# show_dimensions: True
# max_categories: 100
# memory_usage: True
# max_columns: 1000
# max_colwidth: 1000
# float_format: <function <lambda> at 0x7fc9f19c5040>

# %%
# Set seed for random number generator.
# seed = np.int(os.times()[4]) # Use this line for better pseudo-random behavior.
seed = 42
print(seed)
# Out:
# 42

# %%
# Attribute Information URL: https://www.seattle.gov/Documents/Departments/SDOT/GIS/Collisions_OD.pdf
# Read the Collisions Data CSV file and store it as a DataFrame.
# url="https://opendata.arcgis.com/datasets/5b5c745e0f1f48e7a53acec63a0022ab_0.csv" # HTTPError at 202009151050, using local copy of .csv instead.
# print(os.listdir("..")) # Print list of contents of current working directory.
local_path_to_csv = '~/IBM Data Science Professional Certificate Course/Course 9 - Applied Data Science Capstone/projects/Collisions.csv'
df=pd.read_csv(local_path_to_csv, low_memory=False)

# %%
# View the first few rows of the collisions DataFrame.
df.head()
# Out:
#                X            Y  OBJECTID  INCKEY  COLDETKEY   REPORTNO  \
# 0 -122.320757054 47.609407946         1  328476     329976    EA08706
# 1 -122.319560827 47.662220664         2  328142     329642    EA06882
# 2 -122.327524508 47.604393273         3   20700      20700    1181833
# 3 -122.327524934 47.708621579         4  332126     333626  M16001640
# 4 -122.292120049 47.559009080         5  328238     329738    3857118
#
#       STATUS ADDRTYPE  INTKEY  \
# 0    Matched    Block     nan
# 1    Matched    Block     nan
# 2  Unmatched    Block     nan
# 3  Unmatched    Block     nan
# 4  Unmatched    Block     nan
#
#                                                       LOCATION EXCEPTRSNCODE  \
# 0              BROADWAY BETWEEN E COLUMBIA ST AND BOYLSTON AVE
# 1               8TH AVE NE BETWEEN NE 45TH E ST AND NE 47TH ST
# 2                         JAMES ST BETWEEN 6TH AVE AND 7TH AVE           NaN
# 3      NE NORTHGATE WAY BETWEEN 1ST AVE NE AND NE NORTHGATE DR
# 4  M L KING JR ER WAY S BETWEEN S ANGELINE ST AND S EDMUNDS ST
#
#   EXCEPTRSNDESC SEVERITYCODE                    SEVERITYDESC COLLISIONTYPE  \
# 0           NaN            1  Property Damage Only Collision     Sideswipe
# 1           NaN            1  Property Damage Only Collision    Parked Car
# 2           NaN            0                         Unknown           NaN
# 3           NaN            0                         Unknown           NaN
# 4           NaN            0                         Unknown           NaN
#
#    PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  INJURIES  SERIOUSINJURIES  \
# 0            2         0            0         2         0                0
# 1            2         0            0         2         0                0
# 2            0         0            0         0         0                0
# 3            0         0            0         0         0                0
# 4            0         0            0         0         0                0
#
#    FATALITIES                 INCDATE               INCDTTM  \
# 0           0  2020/01/22 00:00:00+00  1/22/2020 3:21:00 PM
# 1           0  2020/01/07 00:00:00+00   1/7/2020 8:00:00 AM
# 2           0  2004/01/30 00:00:00+00             1/30/2004
# 3           0  2016/01/23 00:00:00+00             1/23/2016
# 4           0  2020/01/26 00:00:00+00             1/26/2020
#
#                               JUNCTIONTYPE  SDOT_COLCODE  \
# 0  Mid-Block (not related to intersection)  11.000000000
# 1  Mid-Block (not related to intersection)  15.000000000
# 2     Mid-Block (but intersection related)  11.000000000
# 3  Mid-Block (not related to intersection)  11.000000000
# 4  Mid-Block (not related to intersection)  28.000000000
#
#                                                SDOT_COLDESC INATTENTIONIND  \
# 0    MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END AT ANGLE            NaN
# 1  MOTOR VEHICLE STRUCK MOTOR VEHICLE, RIGHT SIDE SIDESWIPE            NaN
# 2    MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END AT ANGLE            NaN
# 3    MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END AT ANGLE            NaN
# 4             MOTOR VEHICLE RAN OFF ROAD - HIT FIXED OBJECT            NaN
#
#   UNDERINFL  WEATHER ROADCOND                LIGHTCOND PEDROWNOTGRNT  \
# 0         N  Raining      Wet  Dark - Street Lights On           NaN
# 1         N    Clear      Dry                 Daylight           NaN
# 2       NaN      NaN      NaN                      NaN           NaN
# 3       NaN      NaN      NaN                      NaN           NaN
# 4       NaN      NaN      NaN                      NaN           NaN
#
#          SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0               nan      NaN         11
# 1               nan      NaN         32
# 2 4030032.000000000      NaN        NaN
# 3               nan      NaN
# 4               nan      NaN
#
#                                                             ST_COLDESC  \
# 0  From same direction - both going straight - both moving - sideswipe
# 1                                               One parked--one moving
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#    SEGLANEKEY  CROSSWALKKEY HITPARKEDCAR
# 0           0             0            N
# 1           0             0            Y
# 2           0             0            N
# 3           0             0            N
# 4           0             0            N
#
# [5 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221389 entries, 0 to 221388
# Data columns (total 40 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   X                213918 non-null  float64
#  1   Y                213918 non-null  float64
#  2   OBJECTID         221389 non-null  int64
#  3   INCKEY           221389 non-null  int64
#  4   COLDETKEY        221389 non-null  int64
#  5   REPORTNO         221389 non-null  object
#  6   STATUS           221389 non-null  object
#  7   ADDRTYPE         217677 non-null  object
#  8   INTKEY           71884 non-null   float64
#  9   LOCATION         216801 non-null  object
#  10  EXCEPTRSNCODE    100986 non-null  object
#  11  EXCEPTRSNDESC    11779 non-null   object
#  12  SEVERITYCODE     221388 non-null  object
#  13  SEVERITYDESC     221389 non-null  object
#  14  COLLISIONTYPE    195159 non-null  object
#  15  PERSONCOUNT      221389 non-null  int64
#  16  PEDCOUNT         221389 non-null  int64
#  17  PEDCYLCOUNT      221389 non-null  int64
#  18  VEHCOUNT         221389 non-null  int64
#  19  INJURIES         221389 non-null  int64
#  20  SERIOUSINJURIES  221389 non-null  int64
#  21  FATALITIES       221389 non-null  int64
#  22  INCDATE          221389 non-null  object
#  23  INCDTTM          221389 non-null  object
#  24  JUNCTIONTYPE     209417 non-null  object
#  25  SDOT_COLCODE     221388 non-null  float64
#  26  SDOT_COLDESC     221388 non-null  object
#  27  INATTENTIONIND   30188 non-null   object
#  28  UNDERINFL        195179 non-null  object
#  29  WEATHER          194969 non-null  object
#  30  ROADCOND         195050 non-null  object
#  31  LIGHTCOND        194880 non-null  object
#  32  PEDROWNOTGRNT    5192 non-null    object
#  33  SDOTCOLNUM       127205 non-null  float64
#  34  SPEEDING         9928 non-null    object
#  35  ST_COLCODE       211976 non-null  object
#  36  ST_COLDESC       195159 non-null  object
#  37  SEGLANEKEY       221389 non-null  int64
#  38  CROSSWALKKEY     221389 non-null  int64
#  39  HITPARKEDCAR     221389 non-null  object
# dtypes: float64(5), int64(12), object(23)
# memory usage: 67.6+ MB

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 9.170476236962713 seconds.

# %% [markdown]
# <h2 id="data_wrangling">Data Wrangling</h2>
#
# Steps for working with missing data:
# <ol>
#     <li>Identify missing data.</li>
#     <li>Deal with missing data.</li>
#     <li>Correct data format.</li>
# </ol>

# %% [markdown]
# <h3 id="identifying_missing_data">Identifying Missing Data</h3>
#
# The metadata document that accompanied the data set indicates that certain columns have "sentinel" values
# that indicate an unknown or missing value. Each of these missing values will first be converted into NaN.
# Subsequently, the NaN values will be dropped from the DataFrame.

# %%
# If any row of the collisions DataFrame contains a sentinel value representing "unknown",
# then replace it with NaN. 
# Sentinels for "unknown" are listed in the metadata document that accompanies the dataset.
df_unknowns_converted_to_nan = df.replace(to_replace=\
{"EXCEPTRSNCODE": " ",\
 "EXCEPTRSNDESC": "Not Enough Information, or Insufficient Location Information",\
 "SEVERITYCODE": "0",\
 "SEVERITYDESC": "Unknown",\
 "JUNCTIONTYPE": "Unknown",\
 "WEATHER": "Unknown",\
 "ROADCOND": "Unknown",\
 "LIGHTCOND": "Unknown",\
 "SDOT_COLCODE": float(0),\
 "SDOT_COLDESC": "NOT ENOUGH INFORMATION / NOT APPLICABLE",\
 "ST_COLCODE": " ",\
 "ST_COLDESC": "Not stated"},\
value=np.nan, inplace=False, limit=None, regex=False, method='pad')

df_unknowns_converted_to_nan.replace(to_replace={"ST_COLCODE": "0", }, value=np.nan, inplace=True, limit=None, regex=False, method='pad')

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 15.893427981995046 seconds.

# %% [markdown]
# <h3 id="deal_with_missing_data">Deal with Missing Data</h3>
#
# <ol>
#     <li>Drop the Data
#         <ol>
#             <li>Drop entire row.</li>
#             <li>Drop entire column.</li>
#         </ol>
#     </li>
#     <li>Replace the Data
#         <ol>
#             <li>Replace data by mean.</li>
#             <li>Replace data by frequency.</li>
#             <li>Replace data based on other functions.</li>
#         </ol>
#     </li>
#
# </ol>

# %% [markdown]
# Whole columns should be dropped only if most entries in the column are empty.

# %%
print(list(df.columns))
# Out:
# ['X', 'Y', 'OBJECTID', 'INCKEY', 'COLDETKEY', 'REPORTNO', 'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE', 'EXCEPTRSNDESC', 'SEVERITYCODE', 'SEVERITYDESC', 'COLLISIONTYPE', 'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES', 'INCDATE', 'INCDTTM', 'JUNCTIONTYPE', 'SDOT_COLCODE', 'SDOT_COLDESC', 'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND', 'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING', 'ST_COLCODE', 'ST_COLDESC', 'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR']

# %%
# Drop any column from the collisions DataFrame if it satisfies at least one of the following conditions:
# 1) more than 15% of the column's data is NaN;
# 2) the column only contains unique identification keys, or information not useful for model building;
# 3) the column's data is categorical but does not fit into a small (< 15) number of categories;
# 4) information in the column is redundant because it is already represented by another column;
# 5) it is not clear how to interpret the column's data.
list_of_columns_to_drop = ["ADDRTYPE",\
                           "STATUS",\
                           "OBJECTID",\
                           "INCKEY",\
                           "COLDETKEY",\
                           "REPORTNO",\
                           "INTKEY",\
                           "LOCATION",\
                           "EXCEPTRSNCODE",\
                           "EXCEPTRSNDESC",\
                           "SEVERITYDESC",\
                           "INCDATE",\
                           "INCDTTM",\
                           "JUNCTIONTYPE",\
                           "SDOT_COLCODE",\
                           "SDOT_COLDESC",\
                           "INATTENTIONIND",\
                           "UNDERINFL",\
                           "PEDROWNOTGRNT",\
                           "SDOTCOLNUM",\
                           "SPEEDING",\
                           "ST_COLCODE",\
                           "ST_COLDESC",\
                           "SEGLANEKEY",\
                           "CROSSWALKKEY",\
                           "HITPARKEDCAR"]

# %%
# Drop the selected columns from the DataFrame after converting unknowns to NaN.
# Store the result in a new DataFrame.
df_drop_columns = df_unknowns_converted_to_nan.drop(columns=list_of_columns_to_drop, inplace=False)

# %%
# Drop any row that contains at least one NaN.
df_drop_columns_and_rows = df_drop_columns.dropna(axis="index", how="any", thresh=None, subset=None, inplace=False)

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 16.90800308296457 seconds.

# %% [markdown]
# <h3 id="correct_data_format">Correct Data Format</h3>
#
# Ensure that each data type is appropriate for the corresponding feature.
# Cast columns of type "object" as type "category", but leave all other column types unaltered.

# %%
# Create new DataFrame to store converted data types.
df_converted = pd.DataFrame()

for column in list(df_drop_columns_and_rows.columns):
    if (df_drop_columns_and_rows[column].dtype in [np.dtype('object')]):
        df_converted[column] = df_drop_columns_and_rows[column].astype('category')
    # Copy all other columns to new DataFrame without changing their types.
    else:
        df_converted[column] = df_drop_columns_and_rows[column]

# %%
# Create DataFrame of categorical or integer columns, inclusive.
df_categorical = df_converted.select_dtypes(include=["category", "integer"])

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 17.558542252983898 seconds.

# %% [markdown]
# <h2 id="feature_selection">Feature selection</h2>

# %% [markdown]
# #### Features before One-Hot Encoding

# %%
df_categorical.head()
# Out:
#   SEVERITYCODE COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 0            1     Sideswipe            2         0            0         2
# 1            1    Parked Car            2         0            0         2
# 5            1    Rear Ended            2         0            0         2
# 6            1         Other            2         0            0         1
# 8            1     Sideswipe            2         0            0         2
#
#    INJURIES  SERIOUSINJURIES  FATALITIES   WEATHER ROADCOND  \
# 0         0                0           0   Raining      Wet
# 1         0                0           0     Clear      Dry
# 5         0                0           0     Clear      Dry
# 6         0                0           0     Clear      Wet
# 8         0                0           0  Overcast      Dry
#
#                  LIGHTCOND
# 0  Dark - Street Lights On
# 1                 Daylight
# 5                 Daylight
# 6                 Daylight
# 8                 Daylight
#
# [5 rows x 12 columns]

# %%
df_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171872 entries, 0 to 221388
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SEVERITYCODE     171872 non-null  category
#  1   COLLISIONTYPE    171872 non-null  category
#  2   PERSONCOUNT      171872 non-null  int64
#  3   PEDCOUNT         171872 non-null  int64
#  4   PEDCYLCOUNT      171872 non-null  int64
#  5   VEHCOUNT         171872 non-null  int64
#  6   INJURIES         171872 non-null  int64
#  7   SERIOUSINJURIES  171872 non-null  int64
#  8   FATALITIES       171872 non-null  int64
#  9   WEATHER          171872 non-null  category
#  10  ROADCOND         171872 non-null  category
#  11  LIGHTCOND        171872 non-null  category
# dtypes: category(5), int64(7)
# memory usage: 11.3 MB

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 17.946151037933305 seconds.

# %% [markdown]
# <h2 id="imbalanced_data">Dealing with Imbalanced Data</h2>

# %% [markdown]
# Because the data is imbalanced, we split the DataFrame into four DataFrames, one for each value of the SEVERITYCODE feature.

# %%
print("SEVERITYCODE relative frequencies:")
print(df_categorical["SEVERITYCODE"].value_counts(normalize=True, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 1    0.657943120
# 2    0.323036911
# 2b   0.017111571
# 3    0.001908397
# Name: SEVERITYCODE, Length: 4, dtype: float64

# %%
print("SEVERITYCODE relative frequencies:")
print(df_categorical["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 1     113082
# 2      55521
# 2b      2941
# 3        328
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
df_class_1 = df_categorical[df_categorical['SEVERITYCODE'] == '1']
df_class_2 = df_categorical[df_categorical['SEVERITYCODE'] == '2']
df_class_2b = df_categorical[df_categorical['SEVERITYCODE'] == '2b']
df_class_3 = df_categorical[df_categorical['SEVERITYCODE'] == '3']

# %%
print("SEVERITYCODE relative frequencies:")
print(df_class_1["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 1     113082
# 3          0
# 2b         0
# 2          0
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
print("SEVERITYCODE relative frequencies:")
print(df_class_2["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 2     55521
# 3         0
# 2b        0
# 1         0
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
print("SEVERITYCODE relative frequencies:")
print(df_class_2b["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 2b    2941
# 3        0
# 2        0
# 1        0
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
print("SEVERITYCODE relative frequencies:")
print(df_class_3["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 3     328
# 2b      0
# 2       0
# 1       0
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
# Store and print the size of the all classes.
class_1_size = len(df_class_1)
class_2_size = len(df_class_2)
class_2b_size = len(df_class_2b)
class_3_size = len(df_class_3)
print('class 1 size =', class_1_size)
print('class 2 size =', class_2_size)
print('class 2b size =', class_2b_size)
print('class 3 size =', class_3_size)
print()
# Store and print the size of the minority class.
minority_class_size = len(df_class_3)
print('minority class size =', minority_class_size)
# Out:
# class 1 size = 113082
# class 2 size = 55521
# class 2b size = 2941
# class 3 size = 328
#
# minority class size = 328

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 19.279828171012923 seconds.

# %% [markdown]
# <h2 id='sample_size_class_3'>Balance the Dataset by Sampling all Classes Equally<\h2>

# %%
# This sampling parameter provides conventient control for the oversampling of the minority classes
# and, consequently, for the undersampling of the majority classes.
sampling_parameter = 0.5 * class_3_size

# %%
# Set the size of sample to take from each class of accident severity.
# To balance the dataset, ensure that all samples are of the same size.
sample_size_class_1 = np.int(sampling_parameter)
sample_size_class_2 = np.int(sampling_parameter)
sample_size_class_2b = np.int(sampling_parameter)
sample_size_class_3 = np.int(sampling_parameter)

# %%
# Sample all classes equally, with the number of samples equal to the size of class '3'.
# Replacement flag is boolean with value set as follows:
# If class_size > sample_size, then parameter replace is passed the value True.
# Otherwise, parameter replace is passed the value False.
replaceFlag = bool(class_1_size < sample_size_class_1)
print('bool(class_1_size < sample_size_class_1) = %s' % bool(class_1_size < sample_size_class_1))
df_class_1_sampled = df_class_1.sample(n=sample_size_class_1,replace=replaceFlag, axis='index', random_state=seed)

replaceFlag = bool(class_2_size < sample_size_class_2)
print('bool(class_2_size < sample_size_class_2) = %s' % bool(class_2_size < sample_size_class_2))
df_class_2_sampled = df_class_2.sample(n=sample_size_class_2, replace=replaceFlag, axis='index', random_state=seed)

replaceFlag = bool(class_2b_size < sample_size_class_2b)
print('bool(class_2b_size < sample_size_class_2b) = %s' % bool(class_2b_size < sample_size_class_2b))
df_class_2b_sampled = df_class_2b.sample(n=sample_size_class_2b, replace=replaceFlag, axis='index', random_state=seed)

replaceFlag = bool(class_3_size < sample_size_class_3)
print('bool(class_3_size < sample_size_class_3) = %s' % bool(class_3_size < sample_size_class_3))
df_class_3_sampled = df_class_3.sample(n=sample_size_class_3, replace=replaceFlag, axis='index', random_state=seed)
# Out:
# bool(class_1_size < sample_size_class_1) = False
# bool(class_2_size < sample_size_class_2) = False
# bool(class_2b_size < sample_size_class_2b) = False
# bool(class_3_size < sample_size_class_3) = False

# %%
# Produce a new DataFrame by concatenating the minority class's DataFrame with the undersampled resamples of the non-minority classes.
df_balanced_not_shuffled = pd.concat([df_class_1_sampled, df_class_2_sampled, df_class_2b_sampled, df_class_3_sampled], axis='index')

# %%
# Shuffle the new balanced DataFrame and store it for subsequent train/test splits.
df_balanced = shuffle(df_balanced_not_shuffled, random_state=seed)

# %%
# Verify the new DataFrame is balanced.
print("SEVERITYCODE relative frequencies:")
print(df_balanced["SEVERITYCODE"].value_counts(normalize=False, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 3     164
# 2b    164
# 2     164
# 1     164
# Name: SEVERITYCODE, Length: 4, dtype: int64

# %%
# Verify the new DataFrame is balanced.
print("SEVERITYCODE relative frequencies:")
print(df_balanced["SEVERITYCODE"].value_counts(normalize=True, dropna=False))
# Out:
# SEVERITYCODE relative frequencies:
# 3    0.250000000
# 2b   0.250000000
# 2    0.250000000
# 1    0.250000000
# Name: SEVERITYCODE, Length: 4, dtype: float64

# %% [markdown]
# Let's define a feature set represented by the DataFrame X.

# %%
X = df_balanced.drop(columns=['SEVERITYCODE', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES'], inplace=False)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 656 entries, 54298 to 149840
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   COLLISIONTYPE  656 non-null    category
#  1   PERSONCOUNT    656 non-null    int64
#  2   PEDCOUNT       656 non-null    int64
#  3   PEDCYLCOUNT    656 non-null    int64
#  4   VEHCOUNT       656 non-null    int64
#  5   WEATHER        656 non-null    category
#  6   ROADCOND       656 non-null    category
#  7   LIGHTCOND      656 non-null    category
# dtypes: category(4), int64(4)
# memory usage: 29.7 KB

# %% [markdown]
# We also define the data for the target variable, SEVERITYCODE, by the array y:

# %%
y = df_balanced["SEVERITYCODE"].to_numpy()

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 20.746362859965302 seconds.

# %% [markdown]
# ## Transform the Data

# %% [markdown]
# We normalize the data by transforming it so that it is compatible
# with the machine learning estimators we use in this notebook.
# We use special care with sparse matrix data so as to not destroy the
# structure.

# %%
# Create a OneHotEncoder and fit it to the features.
# Transform the data into a sparse matrix by passing the parameter sparse=True by default.
start_time = default_timer()
print("Fitting OneHotEncoder to training data...")
encoder = OneHotEncoder(sparse=True, handle_unknown='ignore')
#encoder.fit(df_categorical.drop(columns=['SEVERITYCODE', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES'], inplace=False))
encoder.fit(X)
X = encoder.transform(X)
print("Completed in", elapsed_time(start_time), "seconds.")
# Display the categories of the encoder.
print(encoder.get_feature_names())
# Out:
# Fitting OneHotEncoder to training data...
# Completed in 0.030165272066369653 seconds.
# ['x0_Angles' 'x0_Cycles' 'x0_Head On' 'x0_Left Turn' 'x0_Other'
#  'x0_Parked Car' 'x0_Pedestrian' 'x0_Rear Ended' 'x0_Right Turn'
#  'x0_Sideswipe' 'x1_0' 'x1_1' 'x1_2' 'x1_3' 'x1_4' 'x1_5' 'x1_6' 'x1_7'
#  'x1_8' 'x1_9' 'x1_10' 'x1_14' 'x1_31' 'x2_0' 'x2_1' 'x2_2' 'x2_3' 'x2_4'
#  'x3_0' 'x3_1' 'x4_0' 'x4_1' 'x4_2' 'x4_3' 'x4_4' 'x4_5' 'x4_6' 'x5_Clear'
#  'x5_Fog/Smog/Smoke' 'x5_Overcast' 'x5_Partly Cloudy' 'x5_Raining'
#  'x5_Severe Crosswind' 'x5_Snowing' 'x6_Dry' 'x6_Ice' 'x6_Snow/Slush'
#  'x6_Standing Water' 'x6_Wet' 'x7_Dark - No Street Lights'
#  'x7_Dark - Street Lights Off' 'x7_Dark - Street Lights On' 'x7_Dawn'
#  'x7_Daylight' 'x7_Dusk' 'x7_Other']

# %%
type(X)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
X.shape
# Out:
# (656, 56)

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 21.213107023970224 seconds.

# %% [markdown]
# <h2 id="logistic_regression">Building a Logistic Regression Model<\h2>

# %%
t0 = default_timer()
#kfold_cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
number_of_folds = 10
logistic_regression_clf = make_pipeline(\
    StandardScaler(with_mean=False),\
    LogisticRegression(solver='saga', multi_class='auto', penalty='l1', max_iter=100, verbose=10, n_jobs=-1, random_state=seed), verbose=True)
scoring = ['f1_macro', 'f1_weighted', 'neg_log_loss', 'precision_macro', 'precision_weighted', 'recall_macro', 'recall_weighted']
logistic_regression_scores = cross_validate(logistic_regression_clf, X, y, scoring=scoring, n_jobs=-1, cv=number_of_folds, return_estimator=True)
print("Logistic regression score keys:", sorted(logistic_regression_scores.keys()))
print('Logistic Regression classifiers constructed in %f seconds.' % elapsed_time(t0))
# Out:
# Logistic regression score keys: ['estimator', 'fit_time', 'score_time', 'test_f1_macro', 'test_f1_weighted', 'test_neg_log_loss', 'test_precision_macro', 'test_precision_weighted', 'test_recall_macro', 'test_recall_weighted']
# Logistic Regression classifiers constructed in 5.557053 seconds.

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 26.927669556927867 seconds.

# %% [markdown]
# <h2 id="support_vector_machine">Building a Support Vector Machine<\h2>

# %%
t0 = default_timer()
number_of_folds = 10
#kfold_cv = StratifiedKFold(n_splits=number_of_folds, shuffle=True, random_state=seed)
linear_svc_clf = make_pipeline(\
    StandardScaler(with_mean=False),\
    LinearSVC(penalty='l1', dual=False, random_state=seed, max_iter=100), verbose=True)
scoring = ['f1_macro', 'f1_weighted', 'precision_macro', 'precision_weighted', 'recall_macro', 'recall_weighted']
linear_svc_scores = cross_validate(linear_svc_clf, X, y, scoring=scoring, n_jobs=-1, cv=number_of_folds, return_estimator=True)
print("Support Vector Machine score keys:", sorted(linear_svc_scores.keys()))
print('Support Vector Machine classifiers constructed in %f seconds.' % elapsed_time(t0))
# Out:
# Support Vector Machine score keys: ['estimator', 'fit_time', 'score_time', 'test_f1_macro', 'test_f1_weighted', 'test_precision_macro', 'test_precision_weighted', 'test_recall_macro', 'test_recall_weighted']
# Support Vector Machine classifiers constructed in 0.516171 seconds.

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 27.628808274981566 seconds.

# %% [markdown]
# <h2 id="knn_classifier">Building a k-Nearsest Neighbors Classifier<\h2>

# %%
t0 = default_timer()
number_of_folds = 10
# Set maximum number of neighbors based on number of samples and number of folds to prevent errors.
maximum_number_of_neighbors = min(200, np.int((X.shape[0] * (1 - 1 / number_of_folds))) - 1) # Take the smaller of the two parameters for min().
k_neighbors_clf = make_pipeline(\
    StandardScaler(with_mean=False),\
    KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski', metric_params=None, n_jobs=-1, p=1, weights='distance'), verbose=True)
# Only us an odd number of neighbors to avoid ties.
#grid_parameters = {'n_neighbors': range(3, maximum_number_of_neighbors, 2),\
#                   'weights': ['distance', 'uniform']} 
grid_parameters = {'kneighborsclassifier__n_neighbors': range(3, maximum_number_of_neighbors, 2)}
scoring = ['recall_macro']
grid_search_cv = GridSearchCV(k_neighbors_clf, param_grid=grid_parameters,\
                              scoring=scoring, \
                              n_jobs=-1, refit='recall_macro', cv=number_of_folds, verbose=100, pre_dispatch=2**8, error_score='raise',\
                              return_train_score=False)
grid_search_cv.fit(X, y)
# Out:
# Fitting 10 folds for each of 99 candidates, totalling 990 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 185 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 186 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 187 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 191 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 193 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 195 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 198 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 201 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 203 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 206 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 207 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 208 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 209 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 211 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 212 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 214 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 215 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 217 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 219 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 220 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 222 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 223 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 227 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done 235 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 236 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 245 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 246 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 251 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done 253 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 258 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 259 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done 261 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done 262 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 265 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 267 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 268 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 269 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 270 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 271 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 274 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 275 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 276 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 277 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 278 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 279 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 281 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 282 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 283 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 285 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 286 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 287 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done 288 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done 289 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 290 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 291 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 293 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 294 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 295 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 296 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 297 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 299 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 301 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 302 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 303 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 307 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 309 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 310 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done 311 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=-1)]: Done 313 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=-1)]: Done 314 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 315 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 316 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 317 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 318 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 319 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 320 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done 321 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done 323 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 324 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 326 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=-1)]: Done 327 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=-1)]: Done 328 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 329 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 331 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 332 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 334 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done 335 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 336 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 337 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 338 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done 339 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done 340 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-1)]: Done 342 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-1)]: Done 343 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 344 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 345 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 346 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 347 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 348 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done 350 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done 351 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 353 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 354 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 355 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 356 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 358 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 359 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 362 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done 363 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 365 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 366 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done 367 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 369 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 371 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 372 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done 373 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done 374 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done 375 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done 377 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done 378 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done 379 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done 382 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done 383 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 385 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 387 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 388 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 389 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 390 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 391 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done 392 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done 393 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done 394 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 395 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 396 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 397 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done 398 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done 399 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 401 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done 403 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done 404 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 405 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 406 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 407 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 408 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 409 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=-1)]: Done 411 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 412 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done 414 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done 415 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 416 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 417 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 419 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=-1)]: Done 420 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=-1)]: Done 421 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 423 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 424 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 425 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 427 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 428 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 429 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 430 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done 431 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done 432 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 433 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 435 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-1)]: Done 436 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-1)]: Done 437 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-1)]: Done 438 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 439 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 440 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 443 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 445 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done 447 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done 448 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done 449 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done 451 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done 452 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done 453 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done 454 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done 455 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 457 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 458 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 459 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 460 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 461 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 462 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done 463 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done 464 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done 465 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done 466 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done 467 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done 468 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 469 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 470 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 471 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 474 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done 475 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done 476 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 477 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 478 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 479 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 480 tasks      | elapsed:   22.2s
# [Parallel(n_jobs=-1)]: Done 481 tasks      | elapsed:   22.2s
# [Parallel(n_jobs=-1)]: Done 482 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 483 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 484 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 485 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 486 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 487 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   22.6s
# [Parallel(n_jobs=-1)]: Done 489 tasks      | elapsed:   22.6s
# [Parallel(n_jobs=-1)]: Done 490 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 491 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 492 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 493 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done 494 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done 495 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 497 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 498 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 499 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 500 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 501 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-1)]: Done 502 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-1)]: Done 503 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=-1)]: Done 505 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=-1)]: Done 506 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 507 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 508 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=-1)]: Done 509 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=-1)]: Done 510 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 511 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 512 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 513 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 514 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 515 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=-1)]: Done 516 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=-1)]: Done 517 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 518 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 519 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 520 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 521 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done 522 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done 523 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 524 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 525 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 526 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 527 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 528 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 529 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 530 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 531 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done 532 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done 533 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 534 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done 535 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done 536 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 538 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 539 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 540 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done 541 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done 542 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done 543 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done 544 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done 545 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done 546 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done 547 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done 548 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done 549 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=-1)]: Done 550 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=-1)]: Done 551 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=-1)]: Done 552 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done 553 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done 554 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done 555 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done 556 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done 557 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 558 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 559 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=-1)]: Done 560 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=-1)]: Done 561 tasks      | elapsed:   25.6s
# [Parallel(n_jobs=-1)]: Done 562 tasks      | elapsed:   25.6s
# [Parallel(n_jobs=-1)]: Done 563 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 564 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 565 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 566 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done 567 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done 569 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 571 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 572 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 573 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 574 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=-1)]: Done 575 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=-1)]: Done 576 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=-1)]: Done 577 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done 578 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done 579 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 580 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 581 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 582 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 583 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done 585 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 586 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 587 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 588 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done 589 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done 590 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done 591 tasks      | elapsed:   26.8s
# [Parallel(n_jobs=-1)]: Done 592 tasks      | elapsed:   26.8s
# [Parallel(n_jobs=-1)]: Done 593 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 594 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 595 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 596 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 597 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 598 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 599 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done 600 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done 601 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 602 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 603 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 604 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=-1)]: Done 606 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done 607 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done 608 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done 609 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 610 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 611 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 612 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 613 tasks      | elapsed:   28.2s
# [Parallel(n_jobs=-1)]: Done 614 tasks      | elapsed:   28.2s
# [Parallel(n_jobs=-1)]: Done 615 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=-1)]: Done 616 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=-1)]: Done 617 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done 618 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done 619 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 620 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 621 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 622 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 623 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done 625 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done 626 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 627 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 628 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 629 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 630 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 631 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 633 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 634 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 635 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 636 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=-1)]: Done 637 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=-1)]: Done 638 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 639 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 641 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 642 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 643 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 644 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 645 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 646 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 647 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 648 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 650 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 651 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 652 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 653 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 654 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 655 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 656 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 657 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 658 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 659 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 660 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 661 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 662 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 663 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 664 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 665 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 666 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 667 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 668 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 669 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 670 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 671 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 672 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 673 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 674 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done 675 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done 676 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 678 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 679 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 680 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 681 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 682 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 683 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 684 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 685 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 686 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 687 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 688 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 689 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 690 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 691 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 692 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done 693 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done 694 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done 695 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 697 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done 698 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done 699 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done 700 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 701 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 702 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 703 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 704 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 705 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 706 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 707 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 708 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 709 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 710 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 711 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=-1)]: Done 712 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=-1)]: Done 713 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 715 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=-1)]: Done 716 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=-1)]: Done 717 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 718 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 719 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 720 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=-1)]: Done 721 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=-1)]: Done 722 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 723 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 724 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 725 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 726 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 727 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 728 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 729 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 730 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-1)]: Done 731 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-1)]: Done 732 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-1)]: Done 733 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done 734 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done 735 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=-1)]: Done 745 out of 990 | elapsed:   33.7s remaining:   11.1s
# [Parallel(n_jobs=-1)]: Done 755 out of 990 | elapsed:   34.0s remaining:   10.6s
# [Parallel(n_jobs=-1)]: Done 765 out of 990 | elapsed:   34.4s remaining:   10.1s
# [Parallel(n_jobs=-1)]: Done 775 out of 990 | elapsed:   34.8s remaining:    9.7s
# [Parallel(n_jobs=-1)]: Done 785 out of 990 | elapsed:   35.2s remaining:    9.2s
# [Parallel(n_jobs=-1)]: Done 795 out of 990 | elapsed:   35.6s remaining:    8.7s
# [Parallel(n_jobs=-1)]: Done 805 out of 990 | elapsed:   36.0s remaining:    8.3s
# [Parallel(n_jobs=-1)]: Done 815 out of 990 | elapsed:   36.3s remaining:    7.8s
# [Parallel(n_jobs=-1)]: Done 825 out of 990 | elapsed:   36.7s remaining:    7.3s
# [Parallel(n_jobs=-1)]: Done 835 out of 990 | elapsed:   37.1s remaining:    6.9s
# [Parallel(n_jobs=-1)]: Done 845 out of 990 | elapsed:   37.5s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done 855 out of 990 | elapsed:   37.8s remaining:    6.0s
# [Parallel(n_jobs=-1)]: Done 865 out of 990 | elapsed:   38.2s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done 875 out of 990 | elapsed:   38.7s remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done 885 out of 990 | elapsed:   39.0s remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done 895 out of 990 | elapsed:   39.4s remaining:    4.2s
# [Parallel(n_jobs=-1)]: Done 905 out of 990 | elapsed:   39.8s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 915 out of 990 | elapsed:   40.2s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 925 out of 990 | elapsed:   40.6s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 935 out of 990 | elapsed:   41.0s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 945 out of 990 | elapsed:   41.4s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 955 out of 990 | elapsed:   41.8s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 965 out of 990 | elapsed:   42.1s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 975 out of 990 | elapsed:   42.6s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 985 out of 990 | elapsed:   42.9s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 990 out of 990 | elapsed:   43.1s finished
# [Pipeline] .... (step 1 of 2) Processing standardscaler, total=   0.0s
# [Pipeline]  (step 2 of 2) Processing kneighborsclassifier, total=   0.0s
# GridSearchCV(cv=10, error_score='raise',
#              estimator=Pipeline(steps=[('standardscaler',
#                                         StandardScaler(with_mean=False)),
#                                        ('kneighborsclassifier',
#                                         KNeighborsClassifier(n_jobs=-1, p=1,
#                                                              weights='distance'))],
#                                 verbose=True),
#              n_jobs=-1,
#              param_grid={'kneighborsclassifier__n_neighbors': range(3, 200, 2)},
#              pre_dispatch=256, refit='recall_macro', scoring=['recall_macro'],
#              verbose=100)

# %%
print('Completed grid search in %f seconds' % (elapsed_time(t0)))
# Out:
# Completed grid search in 43.643408 seconds

# %%
# Store best KNeighborsClassifier from GridSearchCV and print its parameters.
k_neighbors_clf = grid_search_cv.best_estimator_
print('Best KNeighborsClassifier parameters:')
for key in k_neighbors_clf.get_params().keys():
    print(key, ':', k_neighbors_clf.get_params()[key])
# Out:
# Best KNeighborsClassifier parameters:
# memory : None
# steps : [('standardscaler', StandardScaler(with_mean=False)), ('kneighborsclassifier', KNeighborsClassifier(n_jobs=-1, n_neighbors=3, p=1, weights='distance'))]
# verbose : True
# standardscaler : StandardScaler(with_mean=False)
# kneighborsclassifier : KNeighborsClassifier(n_jobs=-1, n_neighbors=3, p=1, weights='distance')
# standardscaler__copy : True
# standardscaler__with_mean : False
# standardscaler__with_std : True
# kneighborsclassifier__algorithm : auto
# kneighborsclassifier__leaf_size : 30
# kneighborsclassifier__metric : minkowski
# kneighborsclassifier__metric_params : None
# kneighborsclassifier__n_jobs : -1
# kneighborsclassifier__n_neighbors : 3
# kneighborsclassifier__p : 1
# kneighborsclassifier__weights : distance

# %%
t0 = default_timer()
number_of_folds = 10
#kfold_cv = StratifiedKFold(n_splits=number_of_folds, shuffle=True, random_state=seed)
scoring = ['f1_macro', 'f1_weighted', 'neg_log_loss', 'precision_macro', 'precision_weighted', 'recall_macro', 'recall_weighted']
k_neighbors_scores = cross_validate(k_neighbors_clf, X, y, scoring=scoring, n_jobs=-1, cv=number_of_folds, return_estimator=True)
print("k-Neighbors score keys:", sorted(k_neighbors_scores.keys()))
print('k-Neighbors Classifiers constructed in %f seconds.' % elapsed_time(t0))
# Out:
# k-Neighbors score keys: ['estimator', 'fit_time', 'score_time', 'test_f1_macro', 'test_f1_weighted', 'test_neg_log_loss', 'test_precision_macro', 'test_precision_weighted', 'test_recall_macro', 'test_recall_weighted']
# k-Neighbors Classifiers constructed in 3.848125 seconds.

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 75.5743099139072 seconds.

# %% [markdown]
# ## Validation of the Models

# %%
# Set starting time for reports and graphics.
t0 = default_timer()

# %%
df_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171872 entries, 0 to 221388
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SEVERITYCODE     171872 non-null  category
#  1   COLLISIONTYPE    171872 non-null  category
#  2   PERSONCOUNT      171872 non-null  int64
#  3   PEDCOUNT         171872 non-null  int64
#  4   PEDCYLCOUNT      171872 non-null  int64
#  5   VEHCOUNT         171872 non-null  int64
#  6   INJURIES         171872 non-null  int64
#  7   SERIOUSINJURIES  171872 non-null  int64
#  8   FATALITIES       171872 non-null  int64
#  9   WEATHER          171872 non-null  category
#  10  ROADCOND         171872 non-null  category
#  11  LIGHTCOND        171872 non-null  category
# dtypes: category(5), int64(7)
# memory usage: 11.3 MB

# %%
# Encode the data using the OneHotEncoder fitted before the models were created.
start_time = default_timer()
print("Transforming full data set's feature set using OneHotEncoder...")
X = df_categorical.drop(columns=['SEVERITYCODE', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES'], inplace=False)
X = encoder.transform(X)
print("Completed in", elapsed_time(start_time), "seconds.")
# Out:
# Transforming full data set's feature set using OneHotEncoder...
# Completed in 0.8737749760039151 seconds.

# %%
y = df_categorical['SEVERITYCODE'].to_numpy()

# %%
X.shape
# Out:
# (171872, 56)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=X.shape[0]-1, random_state=seed, shuffle=True)

# %%
X_test.shape
# Out:
# (171871, 56)

# %%
# Report statistics of the models built for each fold of the cross-validation.
for key in sorted(logistic_regression_scores.keys()):
    if key != 'estimator':
        print('%s: mean = %f, std = %f' % (key, np.mean(logistic_regression_scores[key]), np.std(logistic_regression_scores[key])), sep='')
        print('%s :%s' % (key, logistic_regression_scores[key]), sep='')
        print()
# Out:
# fit_time: mean = 0.373824, std = 0.062946
# fit_time :[0.50821066 0.36191201 0.31119037 0.38585162 0.39903831 0.44048285
#  0.31664753 0.39661121 0.30143237 0.31686115]
#
# score_time: mean = 0.048263, std = 0.018317
# score_time :[0.04871273 0.04501057 0.03596377 0.05181265 0.03647923 0.05104756
#  0.03631067 0.10023665 0.03878546 0.03827143]
#
# test_f1_macro: mean = 0.457705, std = 0.059603
# test_f1_macro :[0.54397998 0.42733888 0.56483516 0.47798591 0.43281131 0.41312076
#  0.38129774 0.46428571 0.48961062 0.38178064]
#
# test_f1_weighted: mean = 0.457694, std = 0.059470
# test_f1_weighted :[0.54436574 0.42565573 0.56405816 0.47625893 0.43236259 0.41233215
#  0.38179767 0.46739927 0.48977046 0.38294006]
#
# test_neg_log_loss: mean = -1.185808, std = 0.109626
# test_neg_log_loss :[-1.06213253 -1.28602596 -1.04295576 -1.10798946 -1.16634001 -1.22826755
#  -1.31937111 -1.10906715 -1.14761422 -1.38831198]
#
# test_precision_macro: mean = 0.470966, std = 0.058950
# test_precision_macro :[0.54340278 0.45652958 0.58333333 0.48268398 0.44351918 0.42309253
#  0.40622605 0.48031136 0.50808081 0.38247863]
#
# test_precision_weighted: mean = 0.471356, std = 0.058353
# test_precision_weighted :[0.54377104 0.4559338  0.58080808 0.48252001 0.44294686 0.42325856
#  0.40766873 0.48475627 0.50846931 0.38343195]
#
# test_recall_macro: mean = 0.460662, std = 0.057836
# test_recall_macro :[0.54503676 0.42647059 0.55974265 0.48805147 0.42463235 0.41084559
#  0.40073529 0.47518382 0.49264706 0.38327206]
#
# test_recall_weighted: mean = 0.460233, std = 0.058140
# test_recall_weighted :[0.54545455 0.42424242 0.56060606 0.48484848 0.42424242 0.40909091
#  0.4        0.47692308 0.49230769 0.38461538]

# %%
# For each logistic regression classifier in the cross-validation, print the macro recall, score report, and confusion matrices.
number_of_models = len(logistic_regression_scores['estimator'])
labels = ['1', '2', '2b', '3']
for index, logistic_regression_clf in zip(range(len(logistic_regression_scores['estimator'])), logistic_regression_scores['estimator']):
    y_test_predicted = logistic_regression_clf.predict(X_test)
    logistic_regression_recall_score = recall_score(y_test, y_test_predicted, average='macro', labels=labels)
    print('Logistic Regression Model %d of %d:' % (index + 1, number_of_models))
    print()
    print(classification_report(y_test, y_test_predicted, labels=labels, target_names=labels, digits=6))
        
    # Create a figure.
    fig = plt.figure(num=str(index + 1), figsize=(6.4 * 3, 4.8))
    fig.suptitle('Confusion Matrices for Logistic Regression Model %d of %d:' % (index + 1, number_of_models), fontsize=20)
    
    ax = plt.subplot(1, 3, 1)
    ax.set_title("Normalized over Predicted Condition", fontsize=12)
    plot_confusion_matrix(logistic_regression_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='pred', ax=ax)
    
    ax = plt.subplot(1, 3, 2)
    ax.set_title("Normalized over True Conditions", fontsize=12)
    plot_confusion_matrix(logistic_regression_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='true', ax=ax)
    
    ax = plt.subplot(1, 3, 3)
    ax.set_title("Not Normalized", fontsize=12)
    plot_confusion_matrix(logistic_regression_clf, X_test, y_test, labels=labels, display_labels=labels, normalize=None, ax=ax)

    plt.show()
# Out:
# Logistic Regression Model 1 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.812815  0.510413  0.627059    113081
#            2   0.405371  0.409197  0.407275     55521
#           2b   0.054554  0.350901  0.094428      2941
#            3   0.006255  0.493902  0.012354       328
#
#     accuracy                       0.474955    171871
#    macro avg   0.319749  0.441103  0.285279    171871
# weighted avg   0.666680  0.474955  0.545773    171871
# Logistic Regression Model 2 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.839759  0.491524  0.620096    113081
#            2   0.402792  0.443238  0.422048     55521
#           2b   0.051487  0.362122  0.090155      2941
#            3   0.006987  0.509146  0.013785       328
#
#     accuracy                       0.473745    171871
#    macro avg   0.325256  0.451507  0.286521    171871
# weighted avg   0.683524  0.473745  0.545894    171871
# Logistic Regression Model 3 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.842673  0.462527  0.597240    113081
#            2   0.401606  0.452261  0.425431     55521
#           2b   0.047943  0.359062  0.084592      2941
#            3   0.006811  0.524390  0.013447       328
#
#     accuracy                       0.457558    171871
#    macro avg   0.324758  0.449560  0.280178    171871
# weighted avg   0.684997  0.457558  0.531853    171871
# Logistic Regression Model 4 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.825751  0.517470  0.636234    113081
#            2   0.412026  0.415410  0.413711     55521
#           2b   0.056048  0.350221  0.096632      2941
#            3   0.006416  0.521341  0.012676       328
#
#     accuracy                       0.481646    171871
#    macro avg   0.325060  0.451111  0.289813    171871
# weighted avg   0.677367  0.481646  0.553927    171871
# Logistic Regression Model 5 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.838361  0.479028  0.609689    113081
#            2   0.396808  0.452297  0.422740     55521
#           2b   0.047517  0.368582  0.084181      2941
#            3   0.007420  0.478659  0.014613       328
#
#     accuracy                       0.468503    171871
#    macro avg   0.322526  0.444642  0.282806    171871
# weighted avg   0.680604  0.468503  0.539169    171871
# Logistic Regression Model 6 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.820957  0.517682  0.634965    113081
#            2   0.413107  0.417482  0.415283     55521
#           2b   0.054775  0.312819  0.093226      2941
#            3   0.006508  0.548780  0.012863       328
#
#     accuracy                       0.481867    171871
#    macro avg   0.323837  0.449191  0.289084    171871
# weighted avg   0.674541  0.481867  0.553542    171871
# Logistic Regression Model 7 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.836600  0.476313  0.607022    113081
#            2   0.394856  0.468363  0.428480     55521
#           2b   0.057255  0.312479  0.096778      2941
#            3   0.006997  0.545732  0.013818       328
#
#     accuracy                       0.471074    171871
#    macro avg   0.323927  0.450722  0.286524    171871
# weighted avg   0.678980  0.471074  0.539483    171871
# Logistic Regression Model 8 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.855615  0.454241  0.593432    113081
#            2   0.408169  0.465283  0.434859     55521
#           2b   0.046204  0.341040  0.081383      2941
#            3   0.006707  0.548780  0.013251       328
#
#     accuracy                       0.456051    171871
#    macro avg   0.329174  0.452336  0.280731    171871
# weighted avg   0.695602  0.456051  0.532338    171871
# Logistic Regression Model 9 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.849686  0.463243  0.599593    113081
#            2   0.405559  0.476991  0.438384     55521
#           2b   0.046332  0.388643  0.082793      2941
#            3   0.007506  0.463415  0.014773       328
#
#     accuracy                       0.466408    171871
#    macro avg   0.327271  0.448073  0.283886    171871
# weighted avg   0.690862  0.466408  0.537557    171871
# Logistic Regression Model 10 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.821904  0.514994  0.633220    113081
#            2   0.409367  0.433404  0.421043     55521
#           2b   0.060606  0.338660  0.102813      2941
#            3   0.006356  0.500000  0.012553       328
#
#     accuracy                       0.485591    171871
#    macro avg   0.324558  0.446764  0.292407    171871
# weighted avg   0.674055  0.485591  0.554418    171871

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 378.50864142994396 seconds.

# %%
# Report statistics of the models built for each fold of the cross-validation.
for key in sorted(linear_svc_scores.keys()):
    if key != 'estimator':
        print('%s: mean = %f, std = %f' % (key, np.mean(linear_svc_scores[key]), np.std(linear_svc_scores[key])), sep='')
        print('%s :%s' % (key, linear_svc_scores[key]), sep='')
        print()
# Out:
# fit_time: mean = 0.048602, std = 0.010440
# fit_time :[0.05777597 0.04663777 0.07510495 0.04606271 0.04134655 0.0395205
#  0.05076838 0.04839706 0.03774095 0.0426662 ]
#
# score_time: mean = 0.032457, std = 0.004118
# score_time :[0.03407645 0.02924109 0.03544331 0.0295465  0.02734756 0.02816057
#  0.03359032 0.03512144 0.03050327 0.04153967]
#
# test_f1_macro: mean = 0.445291, std = 0.075363
# test_f1_macro :[0.57648173 0.45378185 0.57698623 0.4630087  0.36517653 0.4109931
#  0.34816308 0.4610119  0.40935673 0.38795085]
#
# test_f1_weighted: mean = 0.445045, std = 0.075445
# test_f1_weighted :[0.57645979 0.45274544 0.57670682 0.4612735  0.3639055  0.41026897
#  0.34876206 0.4635348  0.40921278 0.38757678]
#
# test_precision_macro: mean = 0.455821, std = 0.075390
# test_precision_macro :[0.578125   0.48826881 0.59081197 0.47032967 0.36493056 0.41806723
#  0.36714901 0.46428571 0.41865079 0.39759615]
#
# test_precision_weighted: mean = 0.455992, std = 0.075049
# test_precision_weighted :[0.57859848 0.48750197 0.58890184 0.4705489  0.3650463  0.41838554
#  0.36809397 0.46739927 0.41819292 0.39724852]
#
# test_recall_macro: mean = 0.451654, std = 0.071228
# test_recall_macro :[0.57628676 0.45496324 0.57444853 0.47334559 0.38143382 0.41084559
#  0.36948529 0.47518382 0.41544118 0.38511029]
#
# test_recall_weighted: mean = 0.450979, std = 0.071760
# test_recall_weighted :[0.57575758 0.45454545 0.57575758 0.46969697 0.37878788 0.40909091
#  0.36923077 0.47692308 0.41538462 0.38461538]

# %%
# For each support vector machine classifier in the cross-validation, print the macro recall, score report, and confusion matrices.
number_of_models = len(linear_svc_scores['estimator'])
labels = ['1', '2', '2b', '3']
for index, linear_svc_clf in zip(range(len(linear_svc_scores['estimator'])), linear_svc_scores['estimator']):
    y_test_predicted = linear_svc_clf.predict(X_test)
    linear_svc_recall_score = recall_score(y_test, y_test_predicted, average='macro', labels=labels)
    print('Support Vector Machine Model %d of %d:' % (index + 1, number_of_models))
    print()
    print(classification_report(y_test, y_test_predicted, labels=labels, target_names=labels, digits=6))
        
    # Create a figure.
    fig = plt.figure(num=str(index + 1), figsize=(6.4 * 3, 4.8))
    fig.suptitle('Confusion Matrices for Support Vector Machine Model %d of %d:' % (index + 1, number_of_models), fontsize=20)
    
    ax = plt.subplot(1,3,1)
    ax.set_title("Normalized over Predicted Condition", fontsize=12)
    plot_confusion_matrix(linear_svc_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='pred', ax=ax)
    
    ax = plt.subplot(1,3,2)
    ax.set_title("Normalized over True Conditions", fontsize=12)
    plot_confusion_matrix(linear_svc_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='true', ax=ax)
    
    ax = plt.subplot(1,3,3)
    ax.set_title("Not Normalized", fontsize=12)
    plot_confusion_matrix(linear_svc_clf, X_test, y_test, labels=labels, display_labels=labels, normalize=None, ax=ax)
    
    plt.show()
# Out:
# Support Vector Machine Model 1 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.813212  0.518602  0.633322    113081
#            2   0.409175  0.399543  0.404301     55521
#           2b   0.052396  0.353621  0.091268      2941
#            3   0.006149  0.481707  0.012144       328
#
#     accuracy                       0.477247    171871
#    macro avg   0.320233  0.438368  0.285259    171871
# weighted avg   0.668134  0.477247  0.548878    171871
# Support Vector Machine Model 2 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.851788  0.471432  0.606944    113081
#            2   0.401109  0.478143  0.436252     55521
#           2b   0.057028  0.357701  0.098373      2941
#            3   0.006571  0.493902  0.012969       328
#
#     accuracy                       0.471697    171871
#    macro avg   0.329124  0.450295  0.288634    171871
# weighted avg   0.690988  0.471697  0.541968    171871
# Support Vector Machine Model 3 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.846066  0.465100  0.600237    113081
#            2   0.400035  0.456494  0.426404     55521
#           2b   0.053284  0.360762  0.092854      2941
#            3   0.006241  0.503049  0.012329       328
#
#     accuracy                       0.460607    171871
#    macro avg   0.326406  0.446351  0.282956    171871
# weighted avg   0.686812  0.460607  0.534278    171871
# Support Vector Machine Model 4 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.824586  0.525491  0.641908    113081
#            2   0.410683  0.417932  0.414276     55521
#           2b   0.059849  0.352601  0.102329      2941
#            3   0.006390  0.506098  0.012620       328
#
#     accuracy                       0.487750    171871
#    macro avg   0.325377  0.450530  0.292783    171871
# weighted avg   0.676232  0.487750  0.557940    171871
# Support Vector Machine Model 5 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.843151  0.480505  0.612150    113081
#            2   0.399789  0.451037  0.423870     55521
#           2b   0.042197  0.283917  0.073474      2941
#            3   0.007960  0.606707  0.015713       328
#
#     accuracy                       0.467863    171871
#    macro avg   0.323274  0.455542  0.281302    171871
# weighted avg   0.684628  0.467863  0.540972    171871
# Support Vector Machine Model 6 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.830646  0.506133  0.629000    113081
#            2   0.411121  0.437060  0.423694     55521
#           2b   0.059732  0.303638  0.099827      2941
#            3   0.006070  0.536585  0.012005       328
#
#     accuracy                       0.480413    171871
#    macro avg   0.326892  0.445854  0.291131    171871
# weighted avg   0.680358  0.480413  0.552446    171871
# Support Vector Machine Model 7 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.838290  0.471352  0.603417    113081
#            2   0.394486  0.471839  0.429709     55521
#           2b   0.059977  0.313159  0.100672      2941
#            3   0.006598  0.533537  0.013034       328
#
#     accuracy                       0.468921    171871
#    macro avg   0.324838  0.447472  0.286708    171871
# weighted avg   0.680019  0.468921  0.537573    171871
# Support Vector Machine Model 8 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.864569  0.446662  0.589019    113081
#            2   0.408086  0.474649  0.438858     55521
#           2b   0.044755  0.335260  0.078968      2941
#            3   0.006631  0.542683  0.013103       328
#
#     accuracy                       0.453980    171871
#    macro avg   0.331011  0.449814  0.279987    171871
# weighted avg   0.701442  0.453980  0.530685    171871
# Support Vector Machine Model 9 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.854185  0.463641  0.601043    113081
#            2   0.404179  0.475856  0.437099     55521
#           2b   0.044499  0.330500  0.078438      2941
#            3   0.008032  0.570122  0.015841       328
#
#     accuracy                       0.465512    171871
#    macro avg   0.327724  0.460030  0.283105    171871
# weighted avg   0.693346  0.465512  0.538023    171871
# Support Vector Machine Model 10 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.833736  0.506416  0.630103    113081
#            2   0.415001  0.430900  0.422801     55521
#           2b   0.057829  0.400204  0.101056      2941
#            3   0.005321  0.408537  0.010505       328
#
#     accuracy                       0.480017    171871
#    macro avg   0.327972  0.436514  0.291116    171871
# weighted avg   0.683611  0.480017  0.552901    171871

# %%
# Report statistics of the models built for each fold of the cross-validation.
for key in sorted(k_neighbors_scores.keys()):
    if key != 'estimator':
        print('%s: mean = %f, std = %f' % (key, np.mean(k_neighbors_scores[key]), np.std(k_neighbors_scores[key])), sep='')
        print('%s :%s' % (key, k_neighbors_scores[key]), sep='')
        print()
# Out:
# fit_time: mean = 0.015347, std = 0.005999
# fit_time :[0.03009439 0.01402879 0.01460361 0.01130629 0.01330066 0.01139045
#  0.02343798 0.0117743  0.01153159 0.01199985]
#
# score_time: mean = 0.109431, std = 0.018173
# score_time :[0.12029409 0.11372757 0.11980462 0.11118746 0.09366441 0.14026141
#  0.12603855 0.10444069 0.08949304 0.07540059]
#
# test_f1_macro: mean = 0.414137, std = 0.033306
# test_f1_macro :[0.44966216 0.41664842 0.43429858 0.39356061 0.4312987  0.46895354
#  0.37384976 0.4155302  0.40681323 0.35075758]
#
# test_f1_weighted: mean = 0.414989, std = 0.033285
# test_f1_weighted :[0.45192465 0.41760776 0.43274053 0.39148301 0.43259347 0.46868614
#  0.37538568 0.41885403 0.40910157 0.35151515]
#
# test_neg_log_loss: mean = -12.053075, std = 1.992337
# test_neg_log_loss :[ -9.32505761 -11.44392032 -11.44448119 -13.43154455  -8.32019507
#  -12.4092178  -14.70407939 -13.10454711 -11.60806445 -14.73964469]
#
# test_precision_macro: mean = 0.422660, std = 0.040954
# test_precision_macro :[0.48680556 0.42112299 0.43487565 0.41147292 0.450381   0.47960526
#  0.37062325 0.41444959 0.40794555 0.34932306]
#
# test_precision_weighted: mean = 0.423416, std = 0.040853
# test_precision_weighted :[0.48703704 0.42217631 0.43358571 0.41138981 0.45091532 0.48098086
#  0.37151476 0.41686465 0.40976664 0.34993177]
#
# test_recall_macro: mean = 0.425827, std = 0.037131
# test_recall_macro :[0.48253676 0.42371324 0.44117647 0.41268382 0.45220588 0.47150735
#  0.38235294 0.42647059 0.41268382 0.35294118]
#
# test_recall_weighted: mean = 0.426643, std = 0.037022
# test_recall_weighted :[0.48484848 0.42424242 0.43939394 0.40909091 0.45454545 0.46969697
#  0.38461538 0.43076923 0.41538462 0.35384615]

# %%
# For each k-Nearest Neighbor classifier in the cross-validation, print the macro recall, score report, and confusion matrices.
number_of_models = len(k_neighbors_scores['estimator'])
labels = ['1', '2', '2b', '3']
for index, knn_clf in zip(range(len(k_neighbors_scores['estimator'])), k_neighbors_scores['estimator']):
    y_test_predicted = knn_clf.predict(X_test)
    knn_recall_score = recall_score(y_test, y_test_predicted, average='macro', labels=labels)
    print('k-Nearest Neighbor Model %d of %d:' % (index + 1, number_of_models))
    print()
    print(classification_report(y_test, y_test_predicted, labels=labels, target_names=labels, digits=6))
        
    # Create a figure.
    fig = plt.figure(num=str(index + 1), figsize=(6.4 * 3, 4.8))
    fig.suptitle('Confusion Matrices for k-Nearest Neighbor Model %d of %d:' % (index + 1, number_of_models), fontsize=20)
    
    ax = plt.subplot(1, 3, 1)
    ax.set_title("Normalized over Predicted Condition", fontsize=12)
    plot_confusion_matrix(knn_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='pred', ax=ax)
    
    ax = plt.subplot(1, 3, 2)
    ax.set_title("Normalized over True Conditions", fontsize=12)
    plot_confusion_matrix(knn_clf, X_test, y_test, labels=labels, display_labels=labels, normalize='true', ax=ax)
    
    ax = plt.subplot(1, 3, 3)
    ax.set_title("Not Normalized", fontsize=12)
    plot_confusion_matrix(knn_clf, X_test, y_test, labels=labels, display_labels=labels, normalize=None, ax=ax)

    plt.show()
# Out:
# k-Nearest Neighbor Model 1 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.770206  0.573713  0.657595    113081
#            2   0.390770  0.358837  0.374123     55521
#           2b   0.035445  0.185311  0.059508      2941
#            3   0.009211  0.597561  0.018142       328
#
#     accuracy                       0.497699    171871
#    macro avg   0.301408  0.428855  0.277342    171871
# weighted avg   0.633608  0.497699  0.554568    171871
# k-Nearest Neighbor Model 2 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.783456  0.557574  0.651491    113081
#            2   0.374710  0.325733  0.348509     55521
#           2b   0.034835  0.276777  0.061882      2941
#            3   0.009665  0.582317  0.019014       328
#
#     accuracy                       0.477922    171871
#    macro avg   0.300667  0.435600  0.270224    171871
# weighted avg   0.637129  0.477922  0.542320    171871
# k-Nearest Neighbor Model 3 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.789692  0.533847  0.637042    113081
#            2   0.382439  0.307992  0.341202     55521
#           2b   0.034743  0.343081  0.063096      2941
#            3   0.008214  0.542683  0.016183       328
#
#     accuracy                       0.457640    171871
#    macro avg   0.303772  0.431901  0.264381    171871
# weighted avg   0.643724  0.457640  0.530468    171871
# k-Nearest Neighbor Model 4 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.784290  0.556689  0.651175    113081
#            2   0.371139  0.325282  0.346701     55521
#           2b   0.033645  0.282557  0.060130      2941
#            3   0.010468  0.582317  0.020566       328
#
#     accuracy                       0.477294    171871
#    macro avg   0.299885  0.436711  0.269643    171871
# weighted avg   0.636504  0.477294  0.541501    171871
# k-Nearest Neighbor Model 5 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.787257  0.566850  0.659116    113081
#            2   0.388970  0.321770  0.352193     55521
#           2b   0.036021  0.263516  0.063379      2941
#            3   0.008259  0.579268  0.016286       328
#
#     accuracy                       0.482513    171871
#    macro avg   0.305127  0.432851  0.272744    171871
# weighted avg   0.644253  0.482513  0.548547    171871
# k-Nearest Neighbor Model 6 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.789633  0.533759  0.636960    113081
#            2   0.369765  0.326129  0.346579     55521
#           2b   0.035782  0.289697  0.063696      2941
#            3   0.008476  0.585366  0.016709       328
#
#     accuracy                       0.462609    171871
#    macro avg   0.300914  0.433738  0.265986    171871
# weighted avg   0.639609  0.462609  0.532162    171871
# k-Nearest Neighbor Model 7 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.792175  0.523351  0.630296    113081
#            2   0.372290  0.355091  0.363487     55521
#           2b   0.035625  0.261816  0.062716      2941
#            3   0.008763  0.603659  0.017276       328
#
#     accuracy                       0.464674    171871
#    macro avg   0.302213  0.435979  0.268444    171871
# weighted avg   0.642095  0.464674  0.533224    171871
# k-Nearest Neighbor Model 8 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.788467  0.550039  0.648018    113081
#            2   0.380648  0.321050  0.348318     55521
#           2b   0.034632  0.276777  0.061562      2941
#            3   0.008299  0.573171  0.016361       328
#
#     accuracy                       0.471435    171871
#    macro avg   0.303012  0.430259  0.268565    171871
# weighted avg   0.642337  0.471435  0.539962    171871
# k-Nearest Neighbor Model 9 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.791186  0.534732  0.638158    113081
#            2   0.369522  0.335026  0.351430     55521
#           2b   0.034747  0.280517  0.061835      2941
#            3   0.009081  0.591463  0.017888       328
#
#     accuracy                       0.465977    171871
#    macro avg   0.301134  0.435435  0.267327    171871
# weighted avg   0.640536  0.465977  0.534488    171871
# k-Nearest Neighbor Model 10 of 10:
#
#               precision    recall  f1-score   support
#
#            1   0.791608  0.532707  0.636850    113081
#            2   0.375534  0.338935  0.356297     55521
#           2b   0.034070  0.271676  0.060546      2941
#            3   0.008239  0.557927  0.016238       328
#
#     accuracy                       0.465692    171871
#    macro avg   0.302363  0.425311  0.267483    171871
# weighted avg   0.642742  0.465692  0.535175    171871

# %%
print('Reports and graphics generated in %f seconds' % (elapsed_time(t0)))
# Out:
# Reports and graphics generated in 1629.668420 seconds

# %%
print_elapsed_time(notebook_start_time)
# Out:
# Elapsed time is 1705.4686099030077 seconds.
